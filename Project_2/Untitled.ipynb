# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [C:\Users\sandy\.wdm\drivers\chromedriver\win32\94.0.4606.61\chromedriver.exe] found in cache

# %%
# 2021 Metacritic Top 20 Ratings 
a_base_url = 'https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear'

# %%
# access each link
for x in range(1,21,1):
    new_url = a_base_url + "/" + str(x)
    browser.visit(new_url)
    # scrap title, rating, and services
    # Use Beautiful Soup's find() method to navigate and retrieve attributes
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')

    title = soup.find('span',class_='product_title')
    m_rating = soup.find('span',class_='metascore')
    services = soup.find('span', class_='byline inset_left')
    print('-----------')
    print(title)
    print(new_url)
    print(m_rating)
    print(services)
    
    # Click the 'Next' button on each page
    try:
        browser.links.find_by_partial_text('next').click()
          
    except:
        print("Scraping Complete")
# Out:
# -----------
# <span class="product_title">
# <a href="/tv/hacks/season-1">
#                                         Hacks: Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/1
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Anne Marie Fox/HBO Max </span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/mare-of-easttown/season-1">
#                                         Mare of Easttown: Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/2
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Sarah Shatz/HBO </span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/all-creatures-great-and-small-2021/season-1">
#                                         All Creatures Great and Small (2021): Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/3
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Playground Television</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/beartown/season-1">
#                                         Beartown
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/4
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Niklas Maupoix/HBO </span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/lupin/season-1">
#                                         Lupin: Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/5
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Emmanuel Guimier</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/waffles-and-mochi/season-1">
#                                         Waffles and Mochi: Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/6
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Adam Rose/Netflix</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/1971-the-year-that-music-changed-everything/season-1">
#                                         1971: The Year That Music Changed Everything
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/7
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Apple</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/exterminate-all-the-brutes/season-1">
#                                         Exterminate All the Brutes
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/8
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Library of Congress/Courtesy HBO </span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/we-are-lady-parts/season-1">
#                                         We Are Lady Parts: Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/9
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Saima Khalid/Peacock</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/the-crime-of-the-century/season-1">
#                                         The Crime of the Century
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/10
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>HBO</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/the-black-church-this-is-our-story-this-is-our-song/season-1">
#                                         The Black Church: This Is Our Story, This Is Our Song
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/11
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Courtesy of McGee Media</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/too-close/season-1">
#                                         Too Close: Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/12
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Robert Viglasky/Jed Bessell/AMC+</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/elizabeth-is-missing/season-1">
#                                         Elizabeth Is Missing
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/13
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Courtesy of STV Productions</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/painting-with-john/season-1">
#                                         Painting With John: Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/14
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>HBO</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/hemingway/season-1">
#                                         Hemingway
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/15
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>PBS</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/last-chance-u-basketball/season-1">
#                                         Last Chance U: Basketball: Season 1
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/16
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Netflix</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/its-a-sin/season-1">
#                                         It's a Sin
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/17
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Channel 4</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/romeo-juliet/season-1">
#                                         Romeo &amp; Juliet
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/18
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Courtesy of National Theatre</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/the-underground-railroad/season-1">
#                                         The Underground Railroad
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/19
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Kyle Kaplan/Amazon Studios</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title">
# <a href="/tv/bo-burnham-inside/season-1">
#                                         Bo Burnham: Inside
#                                                                 </a>
# </span>
# https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear/20
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Netflix</span>
# </span>
# Scraping Complete
