# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [C:\Users\sandy\.wdm\drivers\chromedriver\win32\94.0.4606.61\chromedriver.exe] found in cache

# %%
import numpy as np

# Last 3 years Metacritic Top 20 Ratings 

a_base_urlA = np.array([('https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear'),('https://www.metacritic.com/pictures/best-television-shows-of-2020'),('https://www.metacritic.com/pictures/best-new-tv-series-of-2019')])

# %%
# access each link for 2021
for s in (1,2,3):
    if(s==1):
        print('******************** YEAR 2021 ********************')
    elif(s==2):
        print('******************** YEAR 2020 ********************')
    else:
        print('******************** YEAR 2019 ********************')
   
    for x in range(1,21,1):
        
        new_url = a_base_urlA[s-1] + "/" + str(x)
    #     print(a_base_url)
        browser.visit(new_url)
        # scrap title, rating, and services
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        html = browser.html
        # Parse HTML with Beautiful Soup
        soup = BeautifulSoup(html, 'html.parser')

        title = soup.find_all('span', class_='product_title')
        m_rating = soup.find('span', class_='rank')
        services = soup.find('span', class_='byline inset_left')
        for tit in title:
            print('----------------------------------------------------------------------------------------')
            print(tit.text.lstrip())
            print('Rank: ', x)
#             print(services.text)
        

    # Click the 'Next' button on each page
    try:
            browser.links.find_by_partial_text('Next').click()

    except:
            print("Scraping Complete")
            
    print('***************************************************')
    print('Source: ', a_base_urlA[s-1])
    print('***************************************************\n\n\n')
# Out:
# ******************** YEAR 2021 ********************
# ----------------------------------------------------------------------------------------
# Hacks: Season 1
#
#
# Rank:  1
# ----------------------------------------------------------------------------------------
# Mare of Easttown: Season 1
#
#
# Rank:  2
# ----------------------------------------------------------------------------------------
# All Creatures Great and Small (2021): Season 1
#
#
# Rank:  3
# ----------------------------------------------------------------------------------------
# Beartown
#
#
# Rank:  4
# ----------------------------------------------------------------------------------------
# Lupin: Season 1
#
#
# Rank:  5
# ----------------------------------------------------------------------------------------
# Waffles and Mochi: Season 1
#
#
# Rank:  6
# ----------------------------------------------------------------------------------------
# 1971: The Year That Music Changed Everything
#
#
# Rank:  7
# ----------------------------------------------------------------------------------------
# Exterminate All the Brutes
#
#
# Rank:  8
# ----------------------------------------------------------------------------------------
# We Are Lady Parts: Season 1
#
#
# Rank:  9
# ----------------------------------------------------------------------------------------
# The Crime of the Century
#
#
# Rank:  10
# ----------------------------------------------------------------------------------------
# The Black Church: This Is Our Story, This Is Our Song
#
#
# Rank:  11
# ----------------------------------------------------------------------------------------
# Too Close: Season 1
#
#
# Rank:  12
# ----------------------------------------------------------------------------------------
# Elizabeth Is Missing
#
#
# Rank:  13
# ----------------------------------------------------------------------------------------
# Painting With John: Season 1
#
#
# Rank:  14
# ----------------------------------------------------------------------------------------
# Hemingway
#
#
# Rank:  15
# ----------------------------------------------------------------------------------------
# Last Chance U: Basketball: Season 1
#
#
# Rank:  16
# ----------------------------------------------------------------------------------------
# It's a Sin
#
#
# Rank:  17
# ----------------------------------------------------------------------------------------
# Romeo & Juliet
#
#
# Rank:  18
# ----------------------------------------------------------------------------------------
# The Underground Railroad
#
#
# Rank:  19
# ----------------------------------------------------------------------------------------
# Bo Burnham: Inside
#
#
# Rank:  20
# ***************************************************
# Source:  https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear
# ***************************************************
#
#
#
# ******************** YEAR 2020 ********************
# ----------------------------------------------------------------------------------------
# Central Park   (Apple TV+)
# Rank:  1
# ----------------------------------------------------------------------------------------
# Cheer  (Netflix)
# Rank:  2
# ----------------------------------------------------------------------------------------
# The Plot Against America   (HBO)
# Rank:  3
# ----------------------------------------------------------------------------------------
# I'll Be Gone in the Dark   (HBO)
# Rank:  4
# ----------------------------------------------------------------------------------------
# Normal People   (Hulu)
# Rank:  5
# ----------------------------------------------------------------------------------------
# The Midnight Gospel   (Netflix)
# Rank:  6
# ----------------------------------------------------------------------------------------
# Feel Good   (Netflix)
# Rank:  7
# ----------------------------------------------------------------------------------------
# The Good Lord Bird   (Showtime)
# Rank:  8
# ----------------------------------------------------------------------------------------
# Little America   (Apple TV+)
# Rank:  9
# ----------------------------------------------------------------------------------------
# I Hate Suzie   (HBO Max)
# Rank:  10
# ----------------------------------------------------------------------------------------
# Immigration Nation   (Netflix)
# Rank:  11
# ----------------------------------------------------------------------------------------
# Unorthodox   (Netflix)
# Rank:  12
# ----------------------------------------------------------------------------------------
# P-Valley   (Starz)
# Rank:  13
# ----------------------------------------------------------------------------------------
# I May Destroy You   (HBO)
# Rank:  14
# ----------------------------------------------------------------------------------------
# Mrs. America (FX on Hulu)
# Rank:  15
# ----------------------------------------------------------------------------------------
# The Baby-Sitters Club   (Netflix)
# Rank:  16
# ----------------------------------------------------------------------------------------
# Lenox Hill   (Netflix)
# Rank:  17
# ----------------------------------------------------------------------------------------
# Visible: Out on Television  (Apple TV+)
# Rank:  18
# ----------------------------------------------------------------------------------------
# The Last Dance   (ESPN)
# Rank:  19
# ----------------------------------------------------------------------------------------
# City So Real   (Nat Geo)
# Rank:  20
# ***************************************************
# Source:  https://www.metacritic.com/pictures/best-television-shows-of-2020
# ***************************************************
#
#
#
# ******************** YEAR 2019 ********************
# ----------------------------------------------------------------------------------------
# A Black Lady Sketch Show  (HBO)
# Rank:  1
# ----------------------------------------------------------------------------------------
# Russian Doll  (Netflix)
# Rank:  2
# ----------------------------------------------------------------------------------------
# Undone  (Prime Video)
# Rank:  3
# ----------------------------------------------------------------------------------------
# Back to Life  (Showtime)
# Rank:  4
# ----------------------------------------------------------------------------------------
# Ramy (Hulu)
# Rank:  5
# ----------------------------------------------------------------------------------------
# Watchmen  (HBO)
# Rank:  6
# ----------------------------------------------------------------------------------------
# The Dark Crystal: Age of Resistance (Netflix)
# Rank:  7
# ----------------------------------------------------------------------------------------
# Surviving R. Kelly  (Lifetime)
# Rank:  8
# ----------------------------------------------------------------------------------------
# Harley Quinn  (DC Universe)
# Rank:  9
# ----------------------------------------------------------------------------------------
# Los Espookys  (HBO)
# Rank:  10
# ----------------------------------------------------------------------------------------
# Unbelievable  (Netflix)
# Rank:  11
# ----------------------------------------------------------------------------------------
# PEN15  (Hulu)
# Rank:  12
# ----------------------------------------------------------------------------------------
# Sex Education  (Netflix)
# Rank:  13
# ----------------------------------------------------------------------------------------
# State of the Union  (Sundance)
# Rank:  14
# ----------------------------------------------------------------------------------------
# David Makes Man  (OWN)
# Rank:  15
# ----------------------------------------------------------------------------------------
# Tuca & Bertie  (Netflix)
# Rank:  16
# ----------------------------------------------------------------------------------------
# What We Do in the Shadows  (FX)
# Rank:  17
# ----------------------------------------------------------------------------------------
# The Other Two  (Comedy Central)
# Rank:  18
# ----------------------------------------------------------------------------------------
# South Side  (Comedy Central)
# Rank:  19
# ----------------------------------------------------------------------------------------
# Work in Progress  (Showtime)
# Rank:  20
# ***************************************************
# Source:  https://www.metacritic.com/pictures/best-new-tv-series-of-2019
# ***************************************************

# %%
# expected output: 
#                     [{"Name" : "Burnham",
#                     "Rating": 89,
#                     "Services": "HBO",
#                     "href" : "<link to the detailed web page>"
#                     },
#                     {"Name" : "Burnham",
#                     "Rating": 89,
#                     "Services": "HBO",
#                     "href" : "<link to the detailed web page>"
#                     },
#                    {"Name" : "Burnham",
#                     "Rating": 89,
#                     "Services": "HBO",
#                     "href" : "<link to the detailed web page>"
#                     }
#                     ]

# %%
# 2020 Metacritic Top 20 Ratings 
b_base_url = 'https://www.metacritic.com/pictures/best-television-shows-of-2020'
browser.visit(url)

# %%
# access each link for 2020
for x in range(1,21,1):
    new_url = b_base_url + "/" + str(x)
    browser.visit(new_url)
    # scrap title, rating, and services
    # Use Beautiful Soup's find() method to navigate and retrieve attributes
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.find('span',class_='product_title')
    m_rating = soup.find('span',class_='metascore')
    services = soup.find('span', class_='byline inset_left')
    print('-----------')
    print(title),
    print(new_url),
    print(m_rating),
    print(services)
    
    # Click the 'Next' button on each page
    try:
        browser.links.find_by_partial_text('next').click()
          
    except:
        print("Scraping Complete")
# Out:
# -----------
# <span class="product_title"><a href="https://www.metacritic.com/tv/central-park/season-1">Central Park</a>   (Apple TV+)</span>
# https://www.metacritic.com/pictures/best-television-shows-of-2020/1
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Apple</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title"><a href="https://www.metacritic.com/tv/cheer-2020/season-1">Cheer</a>  (Netflix)</span>
# https://www.metacritic.com/pictures/best-television-shows-of-2020/2
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Netflix</span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title"><a href="https://www.metacritic.com/tv/the-plot-against-america/season-1">The Plot Against America</a>   (HBO)</span>
# https://www.metacritic.com/pictures/best-television-shows-of-2020/3
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Michele K. Short </span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title"><a href="https://www.metacritic.com/tv/ill-be-gone-in-the-dark/season-1">I'll Be Gone in the Dark</a>   (HBO)</span>
# https://www.metacritic.com/pictures/best-television-shows-of-2020/4
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>Robyn Van Swank/HBO </span>
# </span>
# Scraping Complete
# -----------
# <span class="product_title"><a href="https://www.metacritic.com/tv/normal-people/season-1">Normal People</a>   (Hulu)</span>
# https://www.metacritic.com/pictures/best-television-shows-of-2020/5
# None
# <span class="byline inset_left">
# <span class="label">photo by </span><span>