# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Prime Video 2019
p19 = Path("Resources/Prime/p_19.csv")
p19_titles = pd.read_csv(p19)
p19_titles = p19_titles.set_index(['Prime Video', 'Year'])
p19_titles
# Out:
#                                     Genres  IMDb  Rotten Tomatoes  \
# Prime Video Year
# True        2019          Mystery,Thriller   6.4               73
#             2019  Comedy,Crime,Drama,Music   6.4               65
#             2019             Comedy,Family   5.5               50
#             2019             Comedy,Family   5.2               50
#             2019     Action,Drama,Thriller   6.2               49
# ...                                    ...   ...              ...
#             2019                    Comedy   4.2               33
#             2019                    Comedy   7.2               33
#             2019                     Drama   4.9               32
#             2019                     Crime   NaN               17
#             2019             Drama, Sci-Fi   8.0               59
#
#                                                     Title
# Prime Video Year
# True        2019                                Fractured
# ...

# %%
# Number of New Shows
p_19 = len(p19_titles["Title"].unique())
p_19
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-c2df76cd3e2e> in <module>
# ...

# %%
# Average IMDb Ranking
p_imdb_19 = p19_titles["IMDb"].mean()
p_imdb_19.round(1)
# Out:
# 5.9

# %%
# top 10 Amazon Movies according to IMDB
p_top10_imdb_19 = p19_titles.sort_values("IMDb", ascending=False)
p_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                                             Genres  IMDb  \
# Title
# Ostatni ludzie Czarnobyla 2                            Documentary   8.6
# Steve Trevino: 'Til Death                                   Comedy   8.4
# Agent Sai Srinivasa Athreya          Comedy,Crime,Mystery,Thriller   8.4
# Pain Warriors                                          Documentary   8.3
# The Days of Noah Part 1: The Flood                     Documentary   8.3
# Rapid Response                                         Documentary   8.2
# Modern Love                                          Drama, Sci-Fi   8.0
# Gully Boy                                      Drama,Music,Romance   8.0
# Rewind                              Horror,Mystery,Sci-Fi,Thriller   8.0
# Andy Murray: Resurfacing                               Documentary   7.9
#
#                                     Rotten Tomatoes  Year
# Title
# Ostatni ludzie Czarnobyla 2                    42.0  2019
# ...

# %%
# Average Rotten Tomatoes Score
p_rot_19 = p19_titles["Rotten Tomatoes"].mean()
p_rot_19.round(1)
# Out:
# 51.5

# %%
# top 10 Amazon Movies according to Rotten Tomatoes
p_top10_rot_19 = p19_titles.sort_values("Rotten Tomatoes", ascending=False)
p_top10_rot_19.set_index("Title").head(10)
# Out:
#                                                           Genres  IMDb  \
# Title
# Gully Boy                                    Drama,Music,Romance   8.0
# The Report                Biography,Crime,Drama,History,Thriller   7.2
# Honey Boy                                                  Drama   7.3
# Knives Out                   Comedy,Crime,Drama,Mystery,Thriller   7.9
# Brittany Runs a Marathon                            Comedy,Drama   6.8
# Invisible Life                                             Drama   7.8
# One Child Nation                             Documentary,History   7.5
# Late Night                                          Comedy,Drama   6.5
# Blow the Man Down                           Comedy,Drama,Mystery   6.4
# The Lighthouse                      Drama,Fantasy,Horror,Mystery   7.5
#
#                           Rotten Tomatoes  Year
# Title
# Gully Boy                            91.0  2019
# The Report                           89.0  2019
# ...

# %%
p20 = Path("Resources/Prime/p_20.csv")
p20_titles = pd.read_csv(p20)
p20_titles = p20_titles.set_index(['Prime Video', 'Year', 'Title'])
p20_titles
# Out:
#                                                                                 Genres  \
# Prime Video Year Title
# True        2020 Door Ke Darshan                                          Comedy,Drama
#                  Maska                                     Action,Comedy,Crime,Fantasy
#                  Hope Ranch                                                     Family
#                  Stray                                                     Documentary
#                  Borat Subsequent Moviefilm                                     Comedy
# ...                                                                                ...
#                  Anxiety Feast                                            Short,Comedy
#                  Halloween Bug-A-Boo!                          Animation,Comedy,Family
#                  The Wilds                             Crime, Drama, Mystery, Thriller
# ...

# %%
titles_20 = len(p20_titles["Title"].unique())
titles_20
# Out:
# 207

# %%
p_imdb_20 = p20_titles["IMDb"].mean()
p_imdb_20.round(1)
# Out:
# 5.6

# %%
p_top10_imdb_20 = p20_titles.sort_values("IMDb", ascending=False)
p_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                                  IMDb  Netflix  Prime Video  \
# Title
# They Come to America IV: Immigration & Politics   9.0    False         True
# Uncle Tom                                         8.8    False         True
# Nicole Burch: Never Been Kissed                   8.5    False         True
# Love Mocktail                                     8.3    False         True
# Dan Cummins: Get Outta Here; Devil!               8.2    False         True
# Sufna                                             8.0    False         True
# The Grand Tour Presents: A Massive Hunt           7.9    False         True
# Sound of Metal                                    7.8    False         True
# Maria Bamford: Weakness Is the Brand              7.8    False         True
# HIT: The First Case                               7.7    False         True
#
#                                                  Rotten Tomatoes
# Title
# ...

# %%
p_rot_20 = p20_titles["Rotten Tomatoes"].mean()
p_rot_20.round(1)
# Out:
# 48.9

# %%
p_top10_rot_20 = p20_titles.sort_values("Rotten Tomatoes", ascending=False)
p_top10_rot_20.set_index("Title").head(10)
# Out:
#                                  IMDb  Netflix  Prime Video  Rotten Tomatoes
# Title
# Borat Subsequent Moviefilm        6.7    False         True             88.0
# Thappad                           6.8    False         True             82.0
# Sound of Metal                    7.8    False         True             80.0
# Sylvie's Love                     6.8    False         True             78.0
# My Spy                            6.4    False         True             76.0
# Guns Akimbo                       6.3    False         True             74.0
# All In: The Fight for Democracy   6.6    False         True             74.0
# Time                              6.8    False         True             73.0
# Unhinged                          6.0    False         True             72.0
# Honest Thief                      6.0    False         True             72.0

# %%
p21 = Path("Resources/Prime/p_21.csv")
p21_titles = pd.read_csv(p21)
p21_titles.grouped_international_data = converted_ufo.groupby(['country', 'state'])set_index("Title")
# Out:
#                                                                  Genres  IMDb  \
# Title
# Awake                            Action,Adventure,Drama,Sci-Fi,Thriller   4.8
# Monster                                  Biography,Crime,Drama,Thriller   6.5
# One Night in Miami...                                             Drama   7.1
# The Tomorrow War                 Action,Adventure,Drama,Sci-Fi,Thriller   6.6
# Our Friend                                                Drama,Romance   7.3
# ...                                                                 ...   ...
# Tell Me Your Secrets          Animation, Action, Drama, Sport, Thriller   7.4
# LuLaRich                                         Comedy, Drama, Musical   7.8
# Them                                                             Comedy   7.3
# Back to the Rafters       Animation, Adventure, Comedy, Family, Fantasy   7.2
# The Underground Railroad                        Comedy, Drama, Thriller   7.4
#
# ...

# %%
titles_21 = len(p21_titles["Title"].unique())
titles_21
# Out:
# 70

# %%
p_imdb_21 = p21_titles["IMDb"].mean()
p_imdb_19.round(1)
# Out:
# 5.9

# %%
p_top10_imdb_21 = p21_titles.sort_values("IMDb", ascending=False)
p_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                  Genres  IMDb  \
# Title
# Mumbai Diaries 26/11       Animation, Action, Adventure, Comedy, Sci-Fi   8.8
# Invincible                              Crime, Drama, Mystery, Thriller   8.7
# P!nk: All I Know So Far                     Documentary,Biography,Music   7.9
# LuLaRich                                         Comedy, Drama, Musical   7.8
# Jathi Ratnalu                                                    Comedy   7.6
# Tell Me Your Secrets          Animation, Action, Drama, Sport, Thriller   7.4
# The Underground Railroad                        Comedy, Drama, Thriller   7.4
# Our Friend                                                Drama,Romance   7.3
# Them                                                             Comedy   7.3
# Back to the Rafters       Animation, Adventure, Comedy, Family, Fantasy   7.2
#
#                           Rotten Tomatoes  Year
# Title
# ...

# %%
p_rot_21 = p21_titles["Rotten Tomatoes"].mean()
p_rot_21.round(1)
# Out:
# 49.7

# %%
p_top10_rot_21 = p21_titles.sort_values("Rotten Tomatoes", ascending=False)
p_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                 Genres  IMDb  \
# Title
# One Night in Miami...                                            Drama   7.1
# The Tomorrow War                Action,Adventure,Drama,Sci-Fi,Thriller   6.6
# Our Friend                                               Drama,Romance   7.3
# Coming 2 America                                                Comedy   5.3
# Tom Clancy's Without Remorse                       Action,Thriller,War   5.8
# The Map of Tiny Perfect Things                  Comedy,Fantasy,Romance   6.8
# Jolt                                                   Action,Thriller   5.5
# Awake                           Action,Adventure,Drama,Sci-Fi,Thriller   4.8
# Jathi Ratnalu                                                   Comedy   7.6
# Monster                                 Biography,Crime,Drama,Thriller   6.5
#
#                                 Rotten Tomatoes  Year
# Title
# ...

# %%
# Netflix
n19 = Path("Resources/Netflix/n_19.csv")
n19_titles = pd.read_csv(n19)
n19_titles.set_index(["Netflix", "Title"])
# Out:
#                                                                                                  Genres  \
# Netflix Title
# True    The Irishman                                                              Biography,Crime,Drama
#         Article 15                                                         Crime,Drama,Mystery,Thriller
#         Dolemite Is My Name                                                      Biography,Comedy,Drama
#         Fyre                                                                    Documentary,Crime,Music
#         The King                                                    Biography,Drama,History,Romance,War
# ...                                                                                                 ...
#         Amit Tandon: Family Tandoncies                                                           Comedy
#         ChuChuTV Bedtime Stories & Moral Stories for Ki...                                          NaN
# ...

# %%
titles_n19 = len(n19_titles["Title"].unique())
titles_n19
# Out:
# 576

# %%
n_imdb_19 = n19_titles["IMDb"].mean()
n_imdb_19.round(1)
# Out:
# 6.2

# %%
n_top10_imdb_19 = n19_titles.sort_values("IMDb", ascending=False)
n_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                                                                   Genres  \
# Title
# The Mandalorian                              Action, Adventure, Drama, Mystery, Thriller
# Rubaru Roshni                                                                Documentary
# Love on the Spectrum                                                       Comedy, Drama
# K. D.                                                       Crime,Drama,Mystery,Thriller
# Dave Chappelle: Sticks & Stones                                                   Comedy
# Oththa Seruppu Size 7                                                     Drama,Thriller
# Super Deluxe                                                 Comedy,Crime,Drama,Thriller
# Mallesham                                                                      Biography
# Dancing with the Birds                                                       Documentary
# ...

# %%
n_rot_19 = n19_titles["Rotten Tomatoes"].mean()
n_rot_19.round(1)
# Out:
# 52.6

# %%
n_top10_rot_19 = n19_titles.sort_values("Rotten Tomatoes", ascending=False)
n_top10_rot_19.set_index("Title").head(10)
# Out:
#                                                              Genres  IMDb  \
# Title
# The Irishman                                  Biography,Crime,Drama   7.8
# Dolemite Is My Name                          Biography,Comedy,Drama   7.3
# Article 15                             Crime,Drama,Mystery,Thriller   8.2
# Fyre                                        Documentary,Crime,Music   7.2
# The King                        Biography,Drama,History,Romance,War   7.2
# I Am Mother                           Drama,Mystery,Sci-Fi,Thriller   6.7
# Tell Me Who I Am                                     Drama,Thriller   7.6
# I Lost My Body                      Animation,Drama,Fantasy,Romance   7.6
# The Boy Who Harnessed the Wind              Biography,Drama,History   7.6
# Always Be My Maybe                                   Comedy,Romance   6.8
#
#                                 Netflix  Rotten Tomatoes  Year
# Title
# The Irishman                       True             98.0  2019
# ...

# %%
n20 = Path("Resources/Netflix/n_20.csv")
n20_titles = pd.read_csv(n20)
n20_titles.set_index("Title")
# Out:
#                                                                                Genres  \
# Title
# David Attenborough: A Life on Our Planet                        Documentary,Biography
# The Social Dilemma                                                  Documentary,Drama
# The Trial of the Chicago 7                                     Drama,History,Thriller
# Miss Americana                                            Documentary,Biography,Music
# The Half of It                                                   Comedy,Drama,Romance
# ...                                                                               ...
# Space Force                                                             Action, Drama
# Extracurricular                                                        Drama, Romance
# Saikojiman Gwaenchanha                                              Action, Adventure
# Barbarians                                Animation, Adventure, Comedy, Family, Music
# ...

# %%
titles_n20 = len(n20_titles["Title"].unique())
titles_n20
# Out:
# 503

# %%
n_imdb_20 = n20_titles["IMDb"].mean()
n_imdb_20.round(1)
# Out:
# 6.1

# %%
n_top10_imdb_20 = n20_titles.sort_values("IMDb", ascending=False)
n_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                                                     Genres  \
# Title
# David Attenborough: A Life on Our Planet             Documentary,Biography
# Saikojiman Gwaenchanha                                   Action, Adventure
# Sky Tour: The Movie                                      Documentary,Music
# The Queen's Gambit                                  Comedy, Drama, Romance
# Best Wishes, Warmest Regards: A Schitt's Creek ...                     NaN
# Normal People                                              Comedy, Romance
# Emicida: AmarElo - It's All for Yesterday                Documentary,Music
# Ben Platt: Live from Radio City Music Hall                           Music
# Kiss the Ground                                                Documentary
# Disclosure                                                  Drama,Thriller
#
#                                                     IMDb  Netflix  \
# Title
# ...

# %%
n_rot_20 = n20_titles["Rotten Tomatoes"].mean()
n_rot_20.round(1)
# Out:
# 52.3

# %%
n_top10_rot_20 = n20_titles.sort_values("Rotten Tomatoes", ascending=False)
n_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                                Genres  IMDb  \
# Title
# David Attenborough: A Life on Our Planet        Documentary,Biography   9.0
# The Social Dilemma                                  Documentary,Drama   7.6
# The Trial of the Chicago 7                     Drama,History,Thriller   7.8
# Miss Americana                            Documentary,Biography,Music   7.4
# The Half of It                                   Comedy,Drama,Romance   6.9
# The Devil All the Time                           Crime,Drama,Thriller   7.1
# Pieces of a Woman                                               Drama   7.1
# Kiss the Ground                                           Documentary   8.3
# Crip Camp: A Disability Revolution                Documentary,History   7.7
# Extraction                                            Action,Thriller   6.7
#
#                                           Netflix  Rotten Tomatoes  Year
# Title
# ...

# %%
n21 = Path("Resources/Netflix/n_21.csv")
n21_titles = pd.read_csv(n21)
n21_titles.set_index("Title")
# Out:
#                                                                        Genres  \
# Title
# Bo Burnham: Inside                                         Comedy,Drama,Music
# The Dig                                               Biography,Drama,History
# Army of the Dead                          Action,Crime,Horror,Sci-Fi,Thriller
# The White Tiger                                                   Crime,Drama
# I Care a Lot                                            Comedy,Crime,Thriller
# ...                                                                       ...
# Post Mortem: No One Dies in Skarnes                    Comedy, Drama, Romance
# Dive Club                                                 Drama, History, War
# Jailbirds New Orleans                                          Drama, Romance
# Ada Twist, Scientist                                            Comedy, Drama
# Countdown: Inspiration4 Mission to Space              Documentary, Reality-TV
#
# ...

# %%
titles_n21 = len(n21_titles["Title"].unique())
titles_n21
# Out:
# 246

# %%
n_imdb_21 = n21_titles["IMDb"].mean()
n_imdb_21.round(1)
# Out:
# 6.3

# %%
n_top10_imdb_21 = n21_titles.sort_values("IMDb", ascending=False)
n_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                     Genres  \
# Title
# Gaetmaeul Chachacha                     Adventure, Drama, Fantasy, Mystery
# 7 Yards: The Chris Norton Story                                Documentary
# In Our Mothers' Gardens                                        Documentary
# Bo Burnham: Inside                                      Comedy,Drama,Music
# Move to Heaven                   Drama, Fantasy, Mystery, Sci-Fi, Thriller
# Young Royals                               Crime, Drama, Mystery, Thriller
# Binsenjo                                           Documentary, Reality-TV
# Mandela                                                       Comedy,Drama
# D.P.                                                       Comedy, Romance
# Mimi                                                          Comedy,Drama
#
#                                  IMDb  Netflix  Rotten Tomatoes
# Title
# Gaetmaeul Chachacha               9.0     True              NaN
# ...

# %%
n_rot_21 = n21_titles["Rotten Tomatoes"].mean()
n_rot_21.round(1)
# Out:
# 54.1

# %%
n_top10_rot_21 = n21_titles.sort_values("Rotten Tomatoes", ascending=False)
n_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                    Genres  \
# Title
# Bo Burnham: Inside                                     Comedy,Drama,Music
# The White Tiger                                               Crime,Drama
# The Dig                                           Biography,Drama,History
# Army of the Dead                      Action,Crime,Horror,Sci-Fi,Thriller
# I Care a Lot                                        Comedy,Crime,Thriller
# Wish Dragon                     Animation,Adventure,Comedy,Family,Fantasy
# Fear Street Part Two: 1978                           Drama,Horror,Mystery
# Gunpowder Milkshake                             Action,Adventure,Thriller
# The Mitchells vs. The Machines                           Comedy,Talk-Show
# The Ice Road                              Action,Adventure,Drama,Thriller
#
#                                 IMDb  Netflix  Rotten Tomatoes
# Title
# Bo Burnham: Inside               8.8     True             81.0
# ...

# %%
# Disney+
d19 = Path("Resources/Disney/d_19.csv")
d19_titles = pd.read_csv(d19)
d19_titles.set_index("Title")
# Out:
#                                                     Disney+  \
# Title
# The Kid                                                True
# Teen Spirit                                            True
# The Flood                                              True
# Pinocchio                                              True
# Avengers: Endgame                                      True
# Toy Story 4                                            True
# Captain Marvel                                         True
# Star Wars: The Rise of Skywalker                       True
# Frozen II                                              True
# Togo                                                   True
# Maleficent: Mistress of Evil                           True
# Descendants 3                                          True
# The Kid Who Would Be King                              True
# Kitbull                                                True
# ...

# %%
titles_d19 = len(d19_titles["Title"].unique())
titles_d19
# Out:
# 50

# %%
d_imdb_19 = d19_titles["IMDb"].mean()
d_imdb_19.round(1)
# Out:
# 6.5

# %%
d_top10_imdb_19 = d19_titles.sort_values("IMDb", ascending=False)
d_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                       Disney+  \
# Title
# Avengers: Endgame                        True
# Okavango: River of Dreams                True
# Kitbull                                  True
# Togo                                     True
# Toy Story 4                              True
# Apollo: Missions to the Moon             True
# Forky Asks a Question: What Is Love?     True
# Into the Grand Canyon                    True
# Float                                    True
# Expedition Amelia                        True
#
#                                                                          Genres  \
# Title
# Avengers: Endgame                                 Action,Adventure,Drama,Sci-Fi
# Okavango: River of Dreams                                           Documentary
# Kitbull                                            Animation,Short,Drama,Family
# Togo                                   Adventure,Biography,Drama,Family,History
# ...

# %%
d_rot_19 = d19_titles["Rotten Tomatoes"].mean()
d_rot_19.round(1)
# Out:
# 51.9

# %%
d_top10_rot_19 = d19_titles.sort_values("Rotten Tomatoes", ascending=False)
d_top10_rot_19.set_index("Title").head(10)
# Out:
#                                   Disney+  \
# Title
# Avengers: Endgame                    True
# Toy Story 4                          True
# Captain Marvel                       True
# Star Wars: The Rise of Skywalker     True
# Frozen II                            True
# Togo                                 True
# Maleficent: Mistress of Evil         True
# Pinocchio                            True
# Descendants 3                        True
# The Kid Who Would Be King            True
#
#                                                                              Genres  \
# Title
# Avengers: Endgame                                     Action,Adventure,Drama,Sci-Fi
# Toy Story 4                               Animation,Adventure,Comedy,Family,Fantasy
# Captain Marvel                                              Action,Adventure,Sci-Fi
# Star Wars: The Rise of Skywalker                    Action,Adventure,Fantasy,Sci-Fi
# ...

# %%
d20 = Path("Resources/Disney/d_20.csv")
d20_titles = pd.read_csv(d20)
d20_titles.set_index("Title")
# Out:
#                                Disney+  \
# Title
# Sky High                          True
# Soul                              True
# Hamilton                          True
# Onward                            True
# Black Is King                     True
# ...                                ...
# Sharkcano                         True
# Texas Storm Squad                 True
# What the Shark?                   True
# Most Wanted Sharks                True
# Doc McStuffins: The Doc Is In     True
#
#                                                                         Genres  \
# Title
# Sky High                                        Adventure,Comedy,Family,Sci-Fi
# Soul                           Animation,Adventure,Comedy,Family,Fantasy,Music
# Hamilton                                       Biography,Drama,History,Musical
# Onward                               Animation,Adventure,Comedy,Family,Fantasy
# ...

# %%
titles_d20 = len(d20_titles["Title"].unique())
titles_d20
# Out:
# 71

# %%
d_imdb_20 = d20_titles["IMDb"].mean()
d_imdb_20.round(1)
# Out:
# 6.6

# %%
d_top10_imdb_20 = d20_titles.sort_values("IMDb", ascending=False)
d_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                            Disney+  \
# Title
# Hamilton                                      True
# Folklore: The Long Pond Studio Sessions       True
# Soul                                          True
# Jane Goodall: The Hope                        True
# India's Wild Leopards                         True
# Born Wild: The Next Generation                True
# Miraculous World: New York, United HeroeZ     True
# Surviving the Mount St. Helens Disaster       True
# From Our Family to Yours                      True
# Out                                           True
#
#                                                                                       Genres  \
# Title
# Hamilton                                                     Biography,Drama,History,Musical
# Folklore: The Long Pond Studio Sessions                              Documentary,Drama,Music
# Soul                                         Animation,Adventure,Comedy,Family,Fantasy,Music
# ...

# %%
d_rot_20 = d20_titles["Rotten Tomatoes"].mean()
d_rot_20.round(1)
# Out:
# 47.8

# %%
d_top10_rot_20 = d20_titles.sort_values("Rotten Tomatoes", ascending=False)
d_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                     Disney+  \
# Title
# Soul                                                   True
# Hamilton                                               True
# Onward                                                 True
# Black Is King                                          True
# Stargirl                                               True
# Timmy Failure: Mistakes Were Made                      True
# The One and Only Ivan                                  True
# Folklore: The Long Pond Studio Sessions                True
# Phineas and Ferb: The Movie: Candace Against th...     True
# Godmothered                                            True
#
#                                                                                                Genres  \
# Title
# Soul                                                  Animation,Adventure,Comedy,Family,Fantasy,Music
# ...

# %%
d21 = Path("Resources/Disney/d_21.csv")
d21_titles = pd.read_csv(d21)
d21_titles.set_index("Title")
# Out:
#                                                     Disney+  \
# Title
# Luca                                                   True
# Raya and the Last Dragon                               True
# 22 vs. Earth                                           True
# The Simpsons: The Good, the Bart, and the Loki         True
# Us Again                                               True
# Flora & Ulysses                                        True
# Miraculous World: Shanghai – The Legend of Lady...     True
# Maggie Simpson in The Force Awakens from Its Nap       True
# Stuntman                                               True
# The Little Prince(ss)                                  True
# Wolfgang                                               True
# Star Wars Biomes                                       True
# Shark Beach with Chris Hemsworth                       True
# Playing with Sharks: The Valerie Taylor Story          True
# ...

# %%
titles_d21 = len(d21_titles["Title"].unique())
titles_d21
# Out:
# 28

# %%
d_rot_21 = d21_titles["IMDb"].mean()
d_rot_21.round(1)
# Out:
# 6.9

# %%
d_top10_imdb_21 = d21_titles.sort_values("IMDb", ascending=False)
d_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                     Disney+  \
# Title
# Us Again                                               True
# Playing with Sharks: The Valerie Taylor Story          True
# Miraculous World: Shanghai – The Legend of Lady...     True
# Luca                                                   True
# The Little Prince(ss)                                  True
# American Eid                                           True
# Raya and the Last Dragon                               True
# My Music Story: Yoshiki                                True
# Let's Be Tigers                                        True
# Rogue Shark?                                           True
#
#                                                                                                Genres  \
# Title
# Us Again                                                         Animation,Short,Drama,Family,Musical
# ...

# %%
d_rot_21 = d21_titles["Rotten Tomatoes"].mean()
d_rot_21.round(1)
# Out:
# 52.2

# %%
d_top10_rot_21 = d21_titles.sort_values("Rotten Tomatoes", ascending=False)
d_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                     Disney+  \
# Title
# Luca                                                   True
# Raya and the Last Dragon                               True
# 22 vs. Earth                                           True
# The Simpsons: The Good, the Bart, and the Loki         True
# Us Again                                               True
# Flora & Ulysses                                        True
# Miraculous World: Shanghai – The Legend of Lady...     True
# Maggie Simpson in The Force Awakens from Its Nap       True
# Stuntman                                               True
# The Little Prince(ss)                                  True
#
#                                                                                                Genres  \
# Title
# Luca                                                        Animation,Adventure,Comedy,Family,Fantasy
# ...

# %%
hb19 = Path("Resources/HBO/hb_19.csv")
hb19_titles = pd.read_csv(hb19)
hb19_titles.set_index("Title")
# Out:
#                                                                          Genres  \
# Title
# Chernobyl                                                                 Drama
# Watchmen                                                                  Drama
# Euphoria                                                                  Drama
# Doom Patrol                                                               Drama
# His Dark Materials                                                        Drama
# Years and Years                                                           Drama
# Primal                                                                    Drama
# Gentleman Jack                                                            Drama
# The Righteous Gemstones                                                   Drama
# Mrs. Fletcher                                                             Drama
# Our Boys                                                                  Drama
# ...

# %%
titles_hb19 = len(hb19_titles["Title"].unique())
titles_hb19
# Out:
# 26

# %%
hb_imdb_19 = hb19_titles["IMDb"].mean()
hb_imdb_19.round(1)
# Out:
# 7.5

# %%
hb_top10_imdb_19 = hb19_titles.sort_values("IMDb", ascending=False)
hb_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                                                   Genres  \
# Title
# Chernobyl                                                          Drama
# Primal                                                             Drama
# Harley Quinn             Animation, Action, Adventure, Fantasy, Thriller
# Years and Years                                                    Drama
# Euphoria                                                           Drama
# Gentleman Jack                                                     Drama
# Watchmen                                 Crime, Drama, Mystery, Thriller
# The Righteous Gemstones                                            Drama
# Watchmen                                                           Drama
# Doom Patrol                                                        Drama
#
#                           HBO  IMDb  Rotten Tomatoes  Year
# Title
# Chernobyl                True   9.4             96.0  2019
# ...

# %%
hb_rot_19 = hb19_titles["Rotten Tomatoes"].mean()
hb_rot_19.round(1)
# Out:
# 86.7

# %%
hb_top10_rot_19 = hb19_titles.sort_values("Rotten Tomatoes", ascending=False)
hb_top10_rot_19.set_index("Title").head(10)
# Out:
#                          Genres   HBO  IMDb  Rotten Tomatoes  Year
# Title
# A Black Lady Sketch Show  Drama  True   7.1            100.0  2019
# Ghosts                    Drama  True   7.8            100.0  2019
# Primal                    Drama  True   8.7            100.0  2019
# Los Espookys              Drama  True   7.5            100.0  2019
# Chernobyl                 Drama  True   9.4             96.0  2019
# Doom Patrol               Drama  True   8.0             95.0  2019
# Watchmen                  Drama  True   8.1             95.0  2019
# Our Boys                  Drama  True   7.4             93.0  2019
# Gentleman Jack            Drama  True   8.2             90.0  2019
# Years and Years           Drama  True   8.4             89.0  2019

# %%
hb20 = Path("Resources/HBO/hb_20.csv")
hb20_titles = pd.read_csv(hb20)
hb20_titles.set_index("Title")
# Out:
#                                                                              Genres  \
# Title
# The Outsider                                                                  Drama
# I Know This Much Is True                                                      Drama
# The Plot Against America                                                      Drama
# Legendary                                                                     Drama
# McMillion$                                                                    Drama
# We're Here                                                                    Drama
# Perry Mason                                                                   Drama
# Love Life                                                                     Drama
# RUN                                                                           Drama
# The New Pope                                                                  Drama
# ...

# %%
titles_hb20 = len(hb20_titles["Title"].unique())
titles_hb20
# Out:
# 31

# %%
hb_imdb_20 = hb20_titles["IMDb"].mean()
hb_imdb_19.round(1)
# Out:
# 7.5

# %%
hb_top10_imdb_20 = hb20_titles.sort_values("IMDb", ascending=False)
hb_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                                    Genres   HBO  IMDb  \
# Title
# Looney Tunes Cartoons                               Drama  True   8.3
# The New Pope                                        Drama  True   8.2
# Keep Your Hands Off Eizouken!                       Drama  True   8.2
# I Know This Much Is True                            Drama  True   8.2
# I May Destroy You                 Biography, Crime, Drama  True   8.1
# We're Here                                          Drama  True   8.0
# The Outsider                                        Drama  True   7.9
# The Not Too Late Show with Elmo                     Drama  True   7.8
# The Outsider                     Crime, Mystery, Thriller  True   7.7
# Raised by Wolves                            Comedy, Drama  True   7.5
#
#                                  Rotten Tomatoes  Year
# Title
# Looney Tunes Cartoons                       88.0  2020
# The New Pope                                90.0  2020
# ...

# %%
hb_rot_20 = hb20_titles["Rotten Tomatoes"].mean()
hb_rot_20.round(1)
# Out:
# 83.8

# %%
hb_top10_rot_20 = hb20_titles.sort_values("Rotten Tomatoes", ascending=False)
hb_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                   Genres   HBO  IMDb  \
# Title
# We're Here                                         Drama  True   8.0
# Betty                                              Drama  True   6.3
# Atlanta's Missing and Murdered: The Lost Children  Drama  True   7.2
# Legendary                                          Drama  True   7.1
# The New Pope                                       Drama  True   8.2
# Katy Keene                                         Drama  True   6.1
# Looney Tunes Cartoons                              Drama  True   8.3
# McMillion$                                         Drama  True   7.2
# The Plot Against America                           Drama  True   7.3
# Craftopia                                          Drama  True   6.0
#
#                                                    Rotten Tomatoes  Year
# Title
# We're Here                                                   100.0  2020
# ...

# %%
hb21 = Path("Resources/HBO/hb_21.csv")
hb21_titles = pd.read_csv(hb21)
hb21_titles.set_index("Title")
# Out:
#                                                                                                Genres  \
# Title
# Scenes from a Marriage                                     Action, Fantasy, Mystery, Sci-Fi, Thriller
# The White Lotus                                                   Action, Adventure, Fantasy, Mystery
# Mare of Easttown                                                                                Drama
# American Horror Stories                                               Crime, Drama, Mystery, Thriller
# Hacks                                                                           Comedy, Drama, Family
# Superman and Lois                                              Action, Comedy, Drama, Fantasy, Sci-Fi
# The Premise                                                 Action, Adventure, Drama, Romance, Sci-Fi
# Tokyo Revengers                                                                  Action, Crime, Drama
# ...

# %%
titles_hb21 = len(hb21_titles["Title"].unique())
titles_hb21
# Out:
# 13

# %%
hb_imdb_21 = hb21_titles["IMDb"].mean()
hb_imdb_21.round(1)
# Out:
# 7.4

# %%
hb_top10_imdb_21 = hb21_titles.sort_values("IMDb", ascending=False)
hb_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                                                Genres  \
# Title
# It's a Sin                                                           Drama, Mystery, Sci-Fi, Thriller
# Mare of Easttown                                                                                Drama
# Tokyo Revengers                                                                  Action, Crime, Drama
# Hacks                                                                           Comedy, Drama, Family
# Scenes from a Marriage                                     Action, Fantasy, Mystery, Sci-Fi, Thriller
# Superman and Lois                                              Action, Comedy, Drama, Fantasy, Sci-Fi
# The White Lotus                                                   Action, Adventure, Fantasy, Mystery
# The Nevers                                          Adventure, Drama, Fantasy, Horror, Sci-Fi, Thr...
# ...

# %%
hb_rot_21 = hb21_titles["Rotten Tomatoes"].mean()
hb_rot_21.round(1)
# Out:
# 71.0

# %%
hb_top10_rot_21 = hb21_titles.sort_values("Rotten Tomatoes", ascending=False)
hb_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                                                Genres  \
# Title
# Mare of Easttown                                                                                Drama
# It's a Sin                                                           Drama, Mystery, Sci-Fi, Thriller
# Hacks                                                                           Comedy, Drama, Family
# Scenes from a Marriage                                     Action, Fantasy, Mystery, Sci-Fi, Thriller
# The Nevers                                          Adventure, Drama, Fantasy, Horror, Sci-Fi, Thr...
# The White Lotus                                                   Action, Adventure, Fantasy, Mystery
# Walker                                                               Action, Adventure, Drama, Sci-Fi
# Superman and Lois                                              Action, Comedy, Drama, Fantasy, Sci-Fi
# ...

# %%
# Apple
a19 = Path("Resources/Apple/a_19.csv")
a19_titles = pd.read_csv(a19)
a19_titles.set_index("Title")
# Out:
#                   Apple         Genres  IMDb  Rotten Tomatoes  Year
# Title
# Modern Love        True  Drama, Sci-Fi   8.0               59  2019
# The Morning Show   True          Drama   8.4               80  2019
# Servant            True          Drama   7.5               76  2019
# Dickinson          True          Drama   7.4               86  2019

# %%
titles_a19 = len(a19_titles["Title"].unique())
titles_a19
# Out:
# 4

# %%
a_imdb_19 = a19_titles["IMDb"].mean()
a_imdb_19.round(1)
# Out:
# 7.8

# %%
a_top10_imdb_19 = a19_titles.sort_values("IMDb", ascending=False)
a_top10_imdb_19.set_index("Title").head(10)
# Out:
#                   Apple         Genres  IMDb  Rotten Tomatoes  Year
# Title
# The Morning Show   True          Drama   8.4               80  2019
# Modern Love        True  Drama, Sci-Fi   8.0               59  2019
# Servant            True          Drama   7.5               76  2019
# Dickinson          True          Drama   7.4               86  2019

# %%
a_rot_19 = a19_titles["Rotten Tomatoes"].mean()
a_rot_19.round(1)
# Out:
# 75.2

# %%
a_top10_rot_19 = a19_titles.sort_values("Rotten Tomatoes", ascending=False)
a_top10_rot_19.head(10)
# Out:
#    Apple         Genres  IMDb  Rotten Tomatoes             Title  Year
# 3   True          Drama   7.4               86         Dickinson  2019
# 1   True          Drama   8.4               80  The Morning Show  2019
# 2   True          Drama   7.5               76           Servant  2019
# 0   True  Drama, Sci-Fi   8.0               59       Modern Love  2019

# %%
a20 = Path("Resources/Apple/a_20.csv")
a20_titles = pd.read_csv(a20)
a20_titles.set_index("Title")
# Out:
#                                 Apple                Genres  IMDb  \
# Title
# Ted Lasso                        True  Comedy, Drama, Sport   8.8
# The Stand                        True                Comedy   5.5
# Home Movie: The Princess Bride   True         Comedy, Drama   7.4
# Defending Jacob                  True                 Drama   7.9
# Little Voice                     True                 Drama   7.2
# Home Before Dark                 True      Mystery thriller   7.5
# For All Mankind                  True               History   7.9
# Trying                           True                 Drama   7.7
# Little America                   True                Comedy   7.5
# Central Park                     True             Animation   6.8
# Mythic Quest                     True                Comedy   7.7
# Visible: Out on Television       True                 LGBTQ   7.4
#
#                                 Rotten Tomatoes  Rotten Tomatoes\t  Year
# Title
# ...

# %%
titles_a20 = len(a20_titles["Title"].unique())
titles_a20
# Out:
# 12

# %%
a_imdb_20 = a20_titles["IMDb"].mean()
a_imdb_20.round(1)
# Out:
# 7.4

# %%
a_top10_imdb_20 = a20_titles.sort_values("IMDb", ascending=False)
a_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                 Apple                Genres  IMDb  \
# Title
# Ted Lasso                        True  Comedy, Drama, Sport   8.8
# Defending Jacob                  True                 Drama   7.9
# For All Mankind                  True               History   7.9
# Trying                           True                 Drama   7.7
# Mythic Quest                     True                Comedy   7.7
# Home Before Dark                 True      Mystery thriller   7.5
# Little America                   True                Comedy   7.5
# Home Movie: The Princess Bride   True         Comedy, Drama   7.4
# Visible: Out on Television       True                 LGBTQ   7.4
# Little Voice                     True                 Drama   7.2
#
#                                 Rotten Tomatoes  Rotten Tomatoes\t  Year
# Title
# Ted Lasso                                   NaN               95.0  2020
# Defending Jacob                            89.0                NaN  2020
# ...

# %%
a_rot_20 = a20_titles["Rotten Tomatoes"].mean()
a_rot_20.round(1)
# Out:
# 53.0

# %%
a_top10_rot_20 = a20_titles.sort_values("Rotten Tomatoes", ascending=False)
a_top10_rot_20.set_index("Title").head(10)
# Out:
#                                 Apple            Genres  IMDb  \
# Title
# Visible: Out on Television       True             LGBTQ   7.4
# Trying                           True             Drama   7.7
# Defending Jacob                  True             Drama   7.9
# For All Mankind                  True           History   7.9
# Mythic Quest                     True            Comedy   7.7
# Home Movie: The Princess Bride   True     Comedy, Drama   7.4
# Home Before Dark                 True  Mystery thriller   7.5
# Little Voice                     True             Drama   7.2
# Little America                   True            Comedy   7.5
# Central Park                     True         Animation   6.8
#
#                                 Rotten Tomatoes  Rotten Tomatoes\t  Year
# Title
# Visible: Out on Television                100.0                NaN  2020
# Trying                                     94.0                NaN  2020
# ...

# %%
a21 = Path("Resources/Apple/a_21.csv")
a21_titles = pd.read_csv(a21)
a21_titles.set_index("Title")
# Out:
#                                               Apple            Genres  IMDb  \
# Title
# Physical                                       True            Comedy   7.3
# The Morning Show                               True             Drama   8.4
# Mr. Corman                                     True             Drama   6.4
# Defending Jacob                                True             Drama   7.9
# Foundation                                     True             Scifi   7.5
# Losing Alice                                   True             Drama   6.6
# Little Voice                                   True             Drama   7.2
# Home Before Dark                               True  Mystery thriller   7.5
# Servant                                        True             Drama   7.5
# The Me You Can't See                           True   Health wellness   5.3
# For All Mankind                                True           History   7.9
# ...

# %%
titles_a21 = len(a21_titles["Title"].unique())
titles_a21
# Out:
# 21

# %%
a_imdb_21 = a21_titles["IMDb"].mean()
a_imdb_21.round(1)
# Out:
# 7.4

# %%
a_top10_imdb_21 = a21_titles.sort_values("IMDb", ascending=False)
a_top10_imdb_21.set_index("Title").head(10)
# Out:
#     Apple            Genres  IMDb  Rotten Tomatoes  \
# 20   True            Comedy   8.8               95
# 1    True             Drama   8.4               80
# 3    True             Drama   7.9               89
# 10   True           History   7.9               85
# 14   True            Horror   7.7               86
# 17   True            Comedy   7.7               85
# 13   True             Drama   7.7               94
# 4    True             Scifi   7.5               60
# 19   True       Documentary   7.5               62
# 7    True  Mystery thriller   7.5               82
#
#                                            Title  Year
# 20                                     Ted Lasso  2020
# 1                               The Morning Show  2019
# 3                                Defending Jacob  2020
# 10                               For All Mankind  2020
# 14                                         Calls  2021
# 17                                  Mythic Quest  2020
# ...

# %%
a_rot_21 = a21_titles["Rotten Tomatoes"].mean()
a_rot_21.round(1)
# Out:
# 80.5

# %%
a_top10_rot_21 = a21_titles.sort_values("Rotten Tomatoes", ascending=False)
a_top10_rot_21.set_index("Title").head(10)
# Out:
#                             Apple            Genres  IMDb  Rotten Tomatoes  \
# Title
# Visible: Out on Television   True             LGBTQ   7.4              100
# Ted Lasso                    True            Comedy   8.8               95
# Trying                       True             Drama   7.7               94
# Defending Jacob              True             Drama   7.9               89
# Dickinson                    True             Drama   7.4               86
# Calls                        True            Horror   7.7               86
# Mythic Quest                 True            Comedy   7.7               85
# Schmigadoon!                 True           Musical   7.3               85
# For All Mankind              True           History   7.9               85
# Home Before Dark             True  Mystery thriller   7.5               82
#
#                             Year
# Title
# Visible: Out on Television  2020
# Ted Lasso                   2020
# ...

# %%
# Hulu
h19 = Path("Resources/Hulu/h_19.csv")
h19_titles = pd.read_csv(h19)
h19_titles.set_index("Title")
# Out:
#                                                       Genres  Hulu  IMDb  \
# Title
# Framing John DeLorean            Documentary,Biography,Drama  True   6.4
# Parasite                               Comedy,Drama,Thriller  True   8.6
# Portrait of a Lady on Fire                     Drama,Romance  True   8.1
# Rocketman                      Biography,Drama,Music,Musical  True   7.3
# Booksmart                                             Comedy  True   7.2
# ...                                                      ...   ...   ...
# After Parkland                                   Documentary  True   6.0
# Where We Go from Here                                  Drama  True   4.9
# Zoo-Head                                     Sci-Fi,Thriller  True   3.6
# Virgin River                                    Crime, Drama  True   7.4
# His Dark Materials          Action, Adventure, Drama, Sci-Fi  True   7.9
#
#                             Rotten Tomatoes  Year
# Title
# ...

# %%
titles_h19 = len(h19_titles["Title"].unique())
titles_h19
# Out:
# 158

# %%
h_imdb_19 = h19_titles["IMDb"].mean()
h_imdb_19.round(1)
# Out:
# 6.0

# %%
h_top10_imdb_19 = h19_titles.sort_values("IMDb", ascending=False)
h_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                                                               Genres  \
# Title
# Parasite                                                       Comedy,Drama,Thriller
# The Biggest Little Farm                                                  Documentary
# Portrait of a Lady on Fire                                             Drama,Romance
# Raise Hell: The Life & Times of Molly Ivins                              Documentary
# Honeyland                                                          Documentary,Drama
# His Dark Materials                                  Action, Adventure, Drama, Sci-Fi
# Ask Dr. Ruth                                                   Documentary,Biography
# The Peanut Butter Falcon                                      Adventure,Comedy,Drama
# Hotel Mumbai                                           Action,Drama,History,Thriller
# Margaret Atwood: A Word After a Word After a Wo...             Documentary,Biography
#
# ...

# %%
h_rot_19 = p19_titles["Rotten Tomatoes"].mean()
h_rot_19.round(1)
# Out:
# 51.5

# %%
h_top10_rot_19 = h19_titles.sort_values("Rotten Tomatoes", ascending=False)
h_top10_rot_19.set_index("Title").head(10)
# Out:
#                                                    Genres  Hulu  IMDb  \
# Title
# Parasite                            Comedy,Drama,Thriller  True   8.6
# Portrait of a Lady on Fire                  Drama,Romance  True   8.1
# Rocketman                   Biography,Drama,Music,Musical  True   7.3
# Booksmart                                          Comedy  True   7.2
# The Peanut Butter Falcon           Adventure,Comedy,Drama  True   7.6
# Fighting With My Family      Biography,Comedy,Drama,Sport  True   7.1
# Terminator: Dark Fate             Action,Adventure,Sci-Fi  True   6.2
# Bombshell                                 Biography,Drama  True   6.8
# The Upside                                   Comedy,Drama  True   7.0
# Hotel Mumbai                Action,Drama,History,Thriller  True   7.6
#
#                             Rotten Tomatoes  Year
# Title
# Parasite                               88.0  2019
# Portrait of a Lady on Fire             80.0  2019
# ...

# %%
h20 = Path("Resources/Hulu/h_20.csv")
h20_titles = pd.read_csv(h20)
h20_titles.set_index("Title")
# Out:
#                                                                  Genres  Hulu  \
# Title
# MOTHER                                             Drama,Horror,Mystery  True
# Born to Play                                                Documentary  True
# Happiest Season                       Comedy,Crime,Drama,Horror,Romance  True
# Big Time Adolescence                                       Comedy,Drama  True
# Another Round                                              Comedy,Drama  True
# ...                                                                 ...   ...
# The Great             Animation, Action, Adventure, Comedy, Crime, F...  True
# For Life              Animation, Short, Action, Adventure, Comedy, D...  True
# A Teacher                                                  Crime, Drama  True
# Love, Victor                             Comedy, Drama, Family, Romance  True
# Solar Opposites                             Documentary, Crime, Mystery  True
#
# ...

# %%
titles_h20 = len(h20_titles["Title"].unique())
titles_h20
# Out:
# 121

# %%
h_imdb_20 = h20_titles["IMDb"].mean()
h_imdb_20.round(1)
# Out:
# 6.0

# %%
h_top10_imdb_20 = h20_titles.sort_values("IMDb", ascending=False)
h_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                                                                             Genres  \
# Title
# Derek DelGaudio's In & of Itself                                                       Documentary
# Collective                                                                             Documentary
# Love, Victor                                                        Comedy, Drama, Family, Romance
# The Great                                        Animation, Action, Adventure, Comedy, Crime, F...
# Solar Opposites                                                        Documentary, Crime, Mystery
# Crock of Gold: A Few Rounds with Shane MacGowan                        Documentary,Biography,Music
# Another Round                                                                         Comedy,Drama
# The Story of Soaps                                                                         History
# ...

# %%
h_rot_20 = h20_titles["Rotten Tomatoes"].mean()
h_rot_20.round(1)
# Out:
# 57.1

# %%
h_top10_rot_20 = h20_titles.sort_values("Rotten Tomatoes", ascending=False)
h_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                               Genres  Hulu  \
# Title
# Happiest Season                    Comedy,Crime,Drama,Horror,Romance  True
# Big Time Adolescence                                    Comedy,Drama  True
# Another Round                                           Comedy,Drama  True
# Palm Springs                          Comedy,Fantasy,Mystery,Romance  True
# Collective                                               Documentary  True
# Run                                                 Mystery,Thriller  True
# The Mole Agent                                           Documentary  True
# The Croods 2               Animation,Adventure,Comedy,Family,Fantasy  True
# Bill & Ted Face the Music              Adventure,Comedy,Music,Sci-Fi  True
# Sputnik                                      Action,Adventure,Sci-Fi  True
#
#                            IMDb  Rotten Tomatoes  Year
# Title
# Happiest Season             6.6             83.0  2020
# ...

# %%
h21 = Path("Resources/Hulu/h_21.csv")
h21_titles = pd.read_csv(h21)
h21_titles.set_index("Title")
# Out:
#                                                                              Genres  \
# Title
# Nomadland                                                                     Drama
# Boss Level                                           Action,Mystery,Sci-Fi,Thriller
# Barb & Star Go to Vista Del Mar                                              Comedy
# Summer of Soul (...or, When the Revolution Coul...                Documentary,Music
# Quo vadis, Aida?                                                  Drama,History,War
# Plan B                                                                       Comedy
# Willy's Wonderland                                    Action,Comedy,Horror,Thriller
# Some Kind of Heaven                                                     Documentary
# The United States vs. Billie Holiday                          Biography,Drama,Music
# Silk Road                                                      Crime,Drama,Thriller
# ...

# %%
titles_h21 = len(h21_titles["Title"].unique())
titles_h21
# Out:
# 39

# %%
h_imdb_21 = h21_titles["IMDb"].mean()
h_imdb_21.round(1)
# Out:
# 6.0

# %%
h_top10_imdb_21 = h21_titles.sort_values("IMDb", ascending=False)
h_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                             Genres  \
# Title
# Olympic Dreams Featuring Jonas Brothers                                      Sport
# Summer of Soul (...or, When the Revolution Coul...               Documentary,Music
# Quo vadis, Aida?                                                 Drama,History,War
# Nomadland                                                                    Drama
# Some Kind of Heaven                                                    Documentary
# MLK/FBI                                                                Documentary
# Boss Level                                          Action,Mystery,Sci-Fi,Thriller
# kid 90                                               Documentary,Biography,History
# Framing Britney Spears                                                 Documentary
# Little Fish                                                   Drama,Romance,Sci-Fi
#
# ...

# %%
h_rot_21 = h21_titles["Rotten Tomatoes"].mean()
h_rot_21.round(1)
# Out:
# 59.6

# %%
h_top10_rot_21 = h21_titles.sort_values("Rotten Tomatoes", ascending=False)
h_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                             Genres  \
# Title
# Nomadland                                                                    Drama
# Boss Level                                          Action,Mystery,Sci-Fi,Thriller
# Barb & Star Go to Vista Del Mar                                             Comedy
# Summer of Soul (...or, When the Revolution Coul...               Documentary,Music
# Quo vadis, Aida?                                                 Drama,History,War
# Plan B                                                                      Comedy
# Willy's Wonderland                                   Action,Comedy,Horror,Thriller
# Some Kind of Heaven                                                    Documentary
# The United States vs. Billie Holiday                         Biography,Drama,Music
# Silk Road                                                     Crime,Drama,Thriller
#
# ...

# %%
plotdata = pd.DataFrame({
    "Prime":[257, 207, 70],
    "Netflix":[576, 503, 246],
    "Disney":[50, 71, 28],
    "HBO":[26, 31, 13],
    "AppleTV":[2, 3, 10],
    "Hulu" :[158, 121, 39]
    }, 
    index=["2019", "2020", "2021"]
)

plotdata.plot(kind="bar", align="center")
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Series Produced per Streaming Service")
plt.xlabel("Streaming Service")
plt.ylabel("Number of New Shows")
# Out:
# Text(0, 0.5, 'Number of New Shows')

# %%
plotdata = pd.DataFrame({
    "Prime":[5.9, 5.6, 5.9],
    "Netflix":[6.2, 6.1, 6.3],
    "Disney":[6.5, 6.6, 6.9],
    "HBO":[7.5, 7.5, 7.4],
    "AppleTV":[8.3, 7.2, 7.3],
    "Hulu" :[6.0, 6.0, 6.0]
    }, 
    index=["2019", "2020", "2021"]
)

plotdata.plot(kind="bar").legend(loc='upper right', ncol=3)
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Average IMDb Score of Series by Streaming Service")
plt.ylim(5.5,8.5, .1)
plt.xlabel("Streaming Service")
plt.ylabel("IMDb Score (avg)")
# Out:
# Text(0, 0.5, 'IMDb Score (avg)')

# %%
plotdata = pd.DataFrame({
    "Prime":[51.5, 48.9, 49.7],
    "Netflix":[52.6, 52.3, 54.1],
    "Disney":[51.9, 47.8, 52.2],
    "HBO":[86.7, 83.8, 71.0],
    "AppleTV":[59.0, 53.0, 48.9],
    "Hulu" :[48.9, 57.1, 59.6]
    }, 
    index=["2019", "2020", "2021"]
)

plotdata.plot(kind="bar", align="center").legend(loc='upper right', ncol=3)
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Average Rotten Tomatoe Score of Series by Streaming Service")
plt.ylim(45,91)
plt.xlabel("Streaming Service")
plt.ylabel("Tomatoe Score (avg)")
# Out:
# Text(0, 0.5, 'Tomatoe Score (avg)')
