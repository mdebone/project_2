# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [C:\Users\sandy\.wdm\drivers\chromedriver\win32\94.0.4606.61\chromedriver.exe] found in cache

# %%
import numpy as np

# Last 3 years Metacritic Top 20 Ratings 

# base_urlA = 'https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear'
a_base_urlA = np.array([('https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear'),('https://www.metacritic.com/pictures/best-television-shows-of-2020'),('https://www.metacritic.com/pictures/best-new-tv-series-of-2019')])

# %%
import pandas as pd

# %%
data = []
for s in (1,2,3):
    if(s==1):
        print('******************** YEAR 2021 ********************')
    elif(s==2):
        print('******************** YEAR 2020 ********************')
    else:
        print('******************** YEAR 2019 ********************')
   
    for x in range(1,21,1):
        
        new_url = a_base_urlA[s-1] + "/" + str(x)
        # print(a_base_url)
        browser.visit(new_url)
        # scrap title, rating, and services
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        html = browser.html
        # Parse HTML with Beautiful Soup
        soup = BeautifulSoup(html, 'html.parser')

        titles = soup.find_all('span', class_='product_title')
        m_rating = soup.find('span', class_='rank')
        services = soup.find('span', class_='byline inset_left')
        for title in titles:
            data.append({
                "title": title.text.lstrip(),
                "rank": x,
                "service": services.text
                        })
            print('----------------------------------------------------------------------------------------')
            print(title.text.lstrip())
            print('Rank: ', x)
        

    # Click the 'Next' button on each page
    try:
        browser.links.find_by_partial_text('Next').click()

    except:
        print("Scraping Complete")
            
    print('***************************************************')
    print('Source: ', a_base_urlA[s-1])
    print('***************************************************\n\n\n')
# Out:
# ******************** YEAR 2021 ********************
# ----------------------------------------------------------------------------------------
# Hacks: Season 1
#
#
# Rank:  1
# ----------------------------------------------------------------------------------------
# Mare of Easttown: Season 1
#
#
# Rank:  2
# ----------------------------------------------------------------------------------------
# All Creatures Great and Small (2021): Season 1
#
#
# Rank:  3
# ----------------------------------------------------------------------------------------
# Beartown
#
#
# Rank:  4
# ----------------------------------------------------------------------------------------
# Lupin: Season 1
#
#
# Rank:  5
# ----------------------------------------------------------------------------------------
# Waffles and Mochi: Season 1
#
#
# Rank:  6
# ----------------------------------------------------------------------------------------
# 1971: The Year That Music Changed Everything
#
#
# Rank:  7
# ----------------------------------------------------------------------------------------
# Exterminate All the Brutes
#
#
# Rank:  8
# ----------------------------------------------------------------------------------------
# We Are Lady Parts: Season 1
#
#
# Rank:  9
# ----------------------------------------------------------------------------------------
# The Crime of the Century
#
#
# Rank:  10
# ----------------------------------------------------------------------------------------
# The Black Church: This Is Our Story, This Is Our Song
#
#
# Rank:  11
# ----------------------------------------------------------------------------------------
# Too Close: Season 1
#
#
# Rank:  12
# ----------------------------------------------------------------------------------------
# Elizabeth Is Missing
#
#
# Rank:  13
# ----------------------------------------------------------------------------------------
# Painting With John: Season 1
#
#
# Rank:  14
# ----------------------------------------------------------------------------------------
# Hemingway
#
#
# Rank:  15
# ----------------------------------------------------------------------------------------
# Last Chance U: Basketball: Season 1
#
#
# Rank:  16
# ----------------------------------------------------------------------------------------
# It's a Sin
#
#
# Rank:  17
# ----------------------------------------------------------------------------------------
# Romeo & Juliet
#
#
# Rank:  18
# ----------------------------------------------------------------------------------------
# The Underground Railroad
#
#
# Rank:  19
# ----------------------------------------------------------------------------------------
# Bo Burnham: Inside
#
#
# Rank:  20
# ***************************************************
# Source:  https://www.metacritic.com/pictures/best-tv-shows-of-2021-at-midyear
# ***************************************************
#
#
#
# ******************** YEAR 2020 ********************
# ----------------------------------------------------------------------------------------
# Central Park   (Apple TV+)
# Rank:  1
# ----------------------------------------------------------------------------------------
# Cheer  (Netflix)
# Rank:  2
# ----------------------------------------------------------------------------------------
# The Plot Against America   (HBO)
# Rank:  3
# ----------------------------------------------------------------------------------------
# I'll Be Gone in the Dark   (HBO)
# Rank:  4
# ----------------------------------------------------------------------------------------
# Normal People   (Hulu)
# Rank:  5
# ----------------------------------------------------------------------------------------
# The Midnight Gospel   (Netflix)
# Rank:  6
# ----------------------------------------------------------------------------------------
# Feel Good   (Netflix)
# Rank:  7
# ----------------------------------------------------------------------------------------
# The Good Lord Bird   (Showtime)
# Rank:  8
# ----------------------------------------------------------------------------------------
# Little America   (Apple TV+)
# Rank:  9
# ----------------------------------------------------------------------------------------
# I Hate Suzie   (HBO Max)
# Rank:  10
# ----------------------------------------------------------------------------------------
# Immigration Nation   (Netflix)
# Rank:  11
# ----------------------------------------------------------------------------------------
# Unorthodox   (Netflix)
# Rank:  12
# ----------------------------------------------------------------------------------------
# P-Valley   (Starz)
# Rank:  13
# ----------------------------------------------------------------------------------------
# I May Destroy You   (HBO)
# Rank:  14
# ----------------------------------------------------------------------------------------
# Mrs. America (FX on Hulu)
# Rank:  15
# ----------------------------------------------------------------------------------------
# The Baby-Sitters Club   (Netflix)
# Rank:  16
# ----------------------------------------------------------------------------------------
# Lenox Hill   (Netflix)
# Rank:  17
# ----------------------------------------------------------------------------------------
# Visible: Out on Television  (Apple TV+)
# Rank:  18
# ----------------------------------------------------------------------------------------
# The Last Dance   (ESPN)
# Rank:  19
# ----------------------------------------------------------------------------------------
# City So Real   (Nat Geo)
# Rank:  20
# ***************************************************
# Source:  https://www.metacritic.com/pictures/best-television-shows-of-2020
# ***************************************************
#
#
#
# ******************** YEAR 2019 ********************
# ----------------------------------------------------------------------------------------
# A Black Lady Sketch Show  (HBO)
# Rank:  1
# ----------------------------------------------------------------------------------------
# Russian Doll  (Netflix)
# Rank:  2
# ----------------------------------------------------------------------------------------
# Undone  (Prime Video)
# Rank:  3
# ----------------------------------------------------------------------------------------
# Back to Life  (Showtime)
# Rank:  4
# ----------------------------------------------------------------------------------------
# Ramy (Hulu)
# Rank:  5
# ----------------------------------------------------------------------------------------
# Watchmen  (HBO)
# Rank:  6
# ----------------------------------------------------------------------------------------
# The Dark Crystal: Age of Resistance (Netflix)
# Rank:  7
# ----------------------------------------------------------------------------------------
# Surviving R. Kelly  (Lifetime)
# Rank:  8
# ----------------------------------------------------------------------------------------
# Harley Quinn  (DC Universe)
# Rank:  9
# ----------------------------------------------------------------------------------------
# Los Espookys  (HBO)
# Rank:  10
# ----------------------------------------------------------------------------------------
# Unbelievable  (Netflix)
# Rank:  11
# ----------------------------------------------------------------------------------------
# PEN15  (Hulu)
# Rank:  12
# ----------------------------------------------------------------------------------------
# Sex Education  (Netflix)
# Rank:  13
# ----------------------------------------------------------------------------------------
# State of the Union  (Sundance)
# Rank:  14
# ----------------------------------------------------------------------------------------
# David Makes Man  (OWN)
# Rank:  15
# ----------------------------------------------------------------------------------------
# Tuca & Bertie  (Netflix)
# Rank:  16
# ----------------------------------------------------------------------------------------
# What We Do in the Shadows  (FX)
# Rank:  17
# ----------------------------------------------------------------------------------------
# The Other Two  (Comedy Central)
# Rank:  18
# ----------------------------------------------------------------------------------------
# South Side  (Comedy Central)
# Rank:  19
# ----------------------------------------------------------------------------------------
# Work in Progress  (Showtime)
# Rank:  20
# ***************************************************
# Source:  https://www.metacritic.com/pictures/best-new-tv-series-of-2019
# ***************************************************

# %%
# data = {'Title':['Central Park','Cheer','The Plot Aganist America 'I'll Be Gone in the Dark',],
#         'Rank':[1,2,3,4],
#         'Services':['Apple TV+','Netflix', 'HBO']}

# %%
df = pd.DataFrame(data)
df.to_csv(r'../Resources/Metacritic/Metacritic1.csv', index = False)
df
# Out:
#                                                 title  rank  \
# 0   Hacks: Season 1\n                             ...     1
# 1   Mare of Easttown: Season 1\n                  ...     2
# 2   All Creatures Great and Small (2021): Season 1...     3
# 3   Beartown\n                                    ...     4
# 4   Lupin: Season 1\n                             ...     5
# 5   Waffles and Mochi: Season 1\n                 ...     6
# 6   1971: The Year That Music Changed Everything\n...     7
# 7   Exterminate All the Brutes\n                  ...     8
# 8   We Are Lady Parts: Season 1\n                 ...     9
# 9   The Crime of the Century\n                    ...    10
# 10  The Black Church: This Is Our Story, This Is O...    11
# 11  Too Close: Season 1\n                         ...    12
# 12  Elizabeth Is Missing\n                        ...    13
# 13  Painting With John: Season 1\n                ...    14
# 14  Hemingway\n                                   ...    15
# 15  Last Chance U: Basketball: Season 1\n         ...    16
# 16  It's a Sin\n                                  ...    17
# 17  Romeo & Juliet\n                              ...    18
# 18  The Underground Railroad\n                    ...    19
# 19  Bo Burnham: Inside\n                          ...    20
# 20                         Central Park   (Apple TV+)     1
# 21                                   Cheer  (Netflix)     2
# 22                   The Plot Against America   (HBO)     3
# 23                   I'll Be Gone in the Dark   (HBO)     4
# 24                             Normal People   (Hulu)     5
# 25                    The Midnight Gospel   (Netflix)     6
# 26                              Feel Good   (Netflix)     7
# 27                    The Good Lord Bird   (Showtime)     8
# 28                       Little America   (Apple TV+)     9
# 29                           I Hate Suzie   (HBO Max)    10
# 30                     Immigration Nation   (Netflix)    11
# 31                             Unorthodox   (Netflix)    12
# 32                                 P-Valley   (Starz)    13
# 33                          I May Destroy You   (HBO)    14
# 34                          Mrs. America (FX on Hulu)    15
# 35                  The Baby-Sitters Club   (Netflix)    16
# 36                             Lenox Hill   (Netflix)    17
# 37            Visible: Out on Television  (Apple TV+)    18
# 38                            The Last Dance   (ESPN)    19
# 39                           City So Real   (Nat Geo)    20
# 40                    A Black Lady Sketch Show  (HBO)     1
# 41                            Russian Doll  (Netflix)     2
# 42                              Undone  (Prime Video)     3
# 43                           Back to Life  (Showtime)     4
# 44                                        Ramy (Hulu)     5
# 45                                    Watchmen  (HBO)     6
# 46      The Dark Crystal: Age of Resistance (Netflix)     7
# 47                     Surviving R. Kelly  (Lifetime)     8
# 48                        Harley Quinn  (DC Universe)     9
# 49                                Los Espookys  (HBO)    10
# 50                            Unbelievable  (Netflix)    11
# 51                                      PEN15  (Hulu)    12
# 52                           Sex Education  (Netflix)    13
# 53                     State of the Union  (Sundance)    14
# 54                             David Makes Man  (OWN)    15
# 55                           Tuca & Bertie  (Netflix)    16
# 56                    What We Do in the Shadows  (FX)    17
# 57                    The Other Two  (Comedy Central)    18
# 58                       South Side  (Comedy Central)    19
# 59                       Work in Progress  (Showtime)    20
#
#                                               service
# 0                \nphoto by Anne Marie Fox/HBO Max \n
