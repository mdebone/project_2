# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Prime Video 2019
p19 = Path("Resources/Prime/p_19.csv")
p19_titles = pd.read_csv(p19)
p19_titles.set_index("Title")
# Out:
#                                                            Genres  IMDb  \
# Title
# Fractured                                        Mystery,Thriller   6.4
# Beats                                    Comedy,Crime,Drama,Music   6.4
# House Arrest                                        Comedy,Family   5.5
# Back of the Net                                     Comedy,Family   5.2
# Redemption                                  Action,Drama,Thriller   6.2
# ...                                                           ...   ...
# Drastic Measures                             Crime,Drama,Thriller   5.2
# La Sucursal                                                Comedy   4.2
# Matt Braunger: Finally Live in Portland                    Comedy   7.2
# Modern Prodigal                                             Drama   4.9
# Modern Love                                         Drama, Sci-Fi   8.0
#
#                                          Rotten Tomatoes
# Title
# Fractured                                             73
# Beats                                                 65
# House Arrest                                          50
# Back of the Net                                       50
# Redemption                                            49
# ...                                                  ...
# Drastic Measures                                      34
# La Sucursal                                           33
# Matt Braunger: Finally Live in Portland               33
# Modern Prodigal                                       32
# Modern Love                                           59
#
# [254 rows x 3 columns]

# %%
# Number of New Shows
titles_p19 = len(p19_titles["Title"].unique())
titles_p19
# Out:
# 254

# %%
# Average IMDb Ranking
p_imdb_19 = p19_titles["IMDb"].mean()
p_imdb_19.round(1)
# Out:
# 5.9

# %%
# top 10 Amazon Movies according to IMDB
p_top10_imdb_19 = p19_titles.sort_values("IMDb", ascending=False)
p_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                                             Genres  IMDb  \
# Title
# Ostatni ludzie Czarnobyla 2                            Documentary   8.6
# Steve Trevino: 'Til Death                                   Comedy   8.4
# Agent Sai Srinivasa Athreya          Comedy,Crime,Mystery,Thriller   8.4
# Pain Warriors                                          Documentary   8.3
# The Days of Noah Part 1: The Flood                     Documentary   8.3
# Rapid Response                                         Documentary   8.2
# Modern Love                                          Drama, Sci-Fi   8.0
# Gully Boy                                      Drama,Music,Romance   8.0
# Rewind                              Horror,Mystery,Sci-Fi,Thriller   8.0
# Andy Murray: Resurfacing                               Documentary   7.9
#
#                                     Rotten Tomatoes
# Title
# Ostatni ludzie Czarnobyla 2                      42
# Steve Trevino: 'Til Death                        47
# Agent Sai Srinivasa Athreya                      64
# Pain Warriors                                    48
# The Days of Noah Part 1: The Flood               47
# Rapid Response                                   46
# Modern Love                                      59
# Gully Boy                                        91
# Rewind                                           69
# Andy Murray: Resurfacing                         55

# %%
# Average Rotten Tomatoes Score
p_rot_19 = p19_titles["Rotten Tomatoes"].mean()
p_rot_19.round(1)
# Out:
# 51.7

# %%
# top 10 Amazon Movies according to Rotten Tomatoes
p_top10_rot_19 = p19_titles.sort_values("Rotten Tomatoes", ascending=False)
p_top10_rot_19.set_index("Title").head(10)
# Out:
#                                                           Genres  IMDb  \
# Title
# Gully Boy                                    Drama,Music,Romance   8.0
# The Report                Biography,Crime,Drama,History,Thriller   7.2
# Honey Boy                                                  Drama   7.3
# Brittany Runs a Marathon                            Comedy,Drama   6.8
# Invisible Life                                             Drama   7.8
# Knives Out                   Comedy,Crime,Drama,Mystery,Thriller   7.9
# One Child Nation                             Documentary,History   7.5
# Late Night                                          Comedy,Drama   6.5
# Blow the Man Down                           Comedy,Drama,Mystery   6.4
# Midsommar                          Drama,Horror,Mystery,Thriller   7.1
#
#                           Rotten Tomatoes
# Title
# Gully Boy                              91
# The Report                             89
# Honey Boy                              89
# Brittany Runs a Marathon               85
# Invisible Life                         85
# Knives Out                             85
# One Child Nation                       84
# Late Night                             84
# Blow the Man Down                      82
# Midsommar                              80

# %%
p20 = Path("Resources/Prime/p_20.csv")
titles_p20 = pd.read_csv(p20)
titles_p20.set_index("Title")
# Out:
#                                                      Genres  IMDb  \
# Title
# Door Ke Darshan                                Comedy,Drama   6.2
# Maska                           Action,Comedy,Crime,Fantasy   5.8
# Hope Ranch                                           Family   4.4
# Stray                                           Documentary   7.0
# Borat Subsequent Moviefilm                           Comedy   6.7
# ...                                                     ...   ...
# Claudia Oshry: Disgraced Queen                       Comedy   5.6
# Terror at Bigfoot Pond                             Thriller   1.6
# The Reunited States                             Documentary   4.6
# Konga TNT                              Action,Comedy,Sci-Fi   2.5
# Brash Boys Club                                 Documentary   4.0
#
#                                 Rotten Tomatoes
# Title
# Door Ke Darshan                              50
# Maska                                        49
# Hope Ranch                                   39
# Stray                                        59
# Borat Subsequent Moviefilm                   88
# ...                                         ...
# Claudia Oshry: Disgraced Queen               34
# Terror at Bigfoot Pond                       34
# The Reunited States                          33
# Konga TNT                                    32
# Brash Boys Club                              31
#
# [200 rows x 3 columns]

# %%
titles_p20 = len(p20_titles["Title"].unique())
titles_p20
# Out:
# 200

# %%
p_imdb_20 = p20_titles["IMDb"].mean()
p_imdb_20.round(1)
# Out:
# 5.6

# %%
p_top10_imdb_20 = p20_titles.sort_values("IMDb", ascending=False)
p_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                                                               Genres  \
# Title
# They Come to America IV: Immigration & Politics                          Documentary
# Uncle Tom                                                                Documentary
# Nicole Burch: Never Been Kissed                                               Comedy
# Love Mocktail                                                          Drama,Romance
# Dan Cummins: Get Outta Here; Devil!                                           Comedy
# Sufna                                                                        Romance
# The Grand Tour Presents: A Massive Hunt                             Comedy,Talk-Show
# Sound of Metal                                                           Drama,Music
# Maria Bamford: Weakness Is the Brand                                          Comedy
# HIT: The First Case                              Action,Crime,Drama,Mystery,Thriller
#
#                                                  IMDb  Rotten Tomatoes
# Title
# They Come to America IV: Immigration & Politics   9.0               47
# Uncle Tom                                         8.8               69
# Nicole Burch: Never Been Kissed                   8.5               36
# Love Mocktail                                     8.3               61
# Dan Cummins: Get Outta Here; Devil!               8.2               45
# Sufna                                             8.0               60
# The Grand Tour Presents: A Massive Hunt           7.9               58
# Sound of Metal                                    7.8               80
# Maria Bamford: Weakness Is the Brand              7.8               46
# HIT: The First Case                               7.7               61

# %%
p_rot_20 = p20_titles["Rotten Tomatoes"].mean()
p_rot_20.round(1)
# Out:
# 49.4

# %%
p_top10_rot_20 = p20_titles.sort_values("Rotten Tomatoes", ascending=False)
p_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                       Genres  IMDb  \
# Title
# Borat Subsequent Moviefilm                            Comedy   6.7
# Thappad                                                Drama   6.8
# Sound of Metal                                   Drama,Music   7.8
# Sylvie's Love                            Drama,Music,Romance   6.8
# My Spy                                         Action,Comedy   6.4
# Guns Akimbo                           Action,Comedy,Thriller   6.3
# All In: The Fight for Democracy                  Documentary   6.6
# Time                                             Crime,Drama   6.8
# Unhinged                                     Action,Thriller   6.0
# Honest Thief                     Action,Crime,Drama,Thriller   6.0
#
#                                  Rotten Tomatoes
# Title
# Borat Subsequent Moviefilm                    88
# Thappad                                       82
# Sound of Metal                                80
# Sylvie's Love                                 78
# My Spy                                        76
# Guns Akimbo                                   74
# All In: The Fight for Democracy               74
# Time                                          73
# Unhinged                                      72
# Honest Thief                                  72

# %%
p21 = Path("Resources/Prime/p_21.csv")
titles_p21 = pd.read_csv(p21)
titles_p21.set_index("Title")
# Out:
#                                                                            Genres  \
# Title
# Awake                                      Action,Adventure,Drama,Sci-Fi,Thriller
# Monster                                            Biography,Crime,Drama,Thriller
# One Night in Miami...                                                       Drama
# The Tomorrow War                           Action,Adventure,Drama,Sci-Fi,Thriller
# Our Friend                                                          Drama,Romance
# Coming 2 America                                                           Comedy
# The Map of Tiny Perfect Things                             Comedy,Fantasy,Romance
# Tom Clancy's Without Remorse                                  Action,Thriller,War
# Jolt                                                              Action,Thriller
# Jathi Ratnalu                                                              Comedy
# Parallel                                                    Drama,Sci-Fi,Thriller
# My Heart Can't Beat Unless You Tell It To                            Drama,Horror
# Mary J. Blige's My Life                                               Documentary
# Chick Fight                                             Action,Comedy,Drama,Sport
# P!nk: All I Know So Far                               Documentary,Biography,Music
# Luxor                                                               Drama,Romance
# Son of the South                                                  Biography,Drama
# Hoodman                                                     Crime,Horror,Thriller
# Butchers                                                                   Horror
# Cold Case                                            Crime,Drama,Mystery,Thriller
# American Mobster: Retribution                                              Action
# One and the Same                                                          Mystery
# The Pond                                                     Drama,Horror,Mystery
# Introspectum Motel                                                       Thriller
# Stallone: Frank, That Is                                              Documentary
# Blood Born                                                                 Horror
# Goodbye, Butterfly                                                       Thriller
# Red Woods                                                Adventure,Horror,Mystery
# The Lift                                                   Horror,Sci-Fi,Thriller
# The Alpha Test                                                             Sci-Fi
# Journey to Royal: A WWII Rescue Mission                   Documentary,History,War
# My Brother's Keeper                                                  Drama,Family
# These Streets We Haunt                                              Drama,Fantasy
# Expiry                                                                     Sci-Fi
# The Heiress                                                         Drama,Romance
# Lazarus                                            Horror,Mystery,Sci-Fi,Thriller
# My Beautiful Bride                                                 Drama,Thriller
# Volcanic UFO Mysteries                                                Documentary
# Bottom Feeders                                                             Comedy
# Ape Canyon                                                           Comedy,Drama
# Hot Money                                                             Documentary
# Travis Turner                                                               Drama
# Nightingale: A Melody of Life                                         Drama,Music
# The Believer                                                                Drama
# Kilroy                                                    Biography,Drama,History
# Gun and a Hotel Bible                                                       Drama
# Axeman at Cutters Creek                                                    Horror
# Hampton's Legion                                                       Action,War
# The Bid                                                                    Comedy
# All We Got                                                                  Drama
# Good Grief It's Friday                                              Drama,Musical
# The Healing Garden                                                         Family
# Honesty Weekend                                                            Comedy
# Virus Shark                                                                Horror
# Magic Max                                                                   Drama
# Voyage of the Chimera                                                      Sci-Fi
# Love You Right: An R&B Musical                              Drama,Musical,Romance
# Mummy Dearest                                             Horror,Mystery,Thriller
# Aperture Kids and the Mysterious Neighbor                    Drama,Family,Mystery
# Invincible                                        Crime, Drama, Mystery, Thriller
#
#                                            IMDb  Rotten Tomatoes
# Title
# Awake                                       4.8               63
# Monster                                     6.5               61
# One Night in Miami...                       7.1               86
# The Tomorrow War                            6.6               81
# Our Friend                                  7.3               74
# Coming 2 America                            5.3               70
# The Map of Tiny Perfect Things              6.8               69
# Tom Clancy's Without Remorse                5.8               69
# Jolt                                        5.5               67
# Jathi Ratnalu                               7.6               61
# Parallel                                    5.8               59
# My Heart Can't Beat Unless You Tell It To   6.2               59
# Mary J. Blige's My Life                     6.5               57
# Chick Fight                                 4.6               57
# P!nk: All I Know So Far                     7.9               57
# Luxor                                       5.3               55
# Son of the South                            5.7               54
# Hoodman                                     5.9               54
# Butchers                                    4.6               54
# Cold Case                                   6.1               53
# American Mobster: Retribution               6.3               53
# One and the Same                            6.5               53
# The Pond                                    4.2               50
# Introspectum Motel                          3.7               50
# Stallone: Frank, That Is                    6.5               50
# Blood Born                                  4.0               50
# Goodbye, Butterfly                          4.8               49
# Red Woods                                   3.2               48
# The Lift                                    4.7               48
# The Alpha Test                              3.2               48
# Journey to Royal: A WWII Rescue Mission     5.4               47
# My Brother's Keeper                         5.3               46
# These Streets We Haunt                      4.8               46
# Expiry                                      4.4               46
# The Heiress                                 4.7               46
# Lazarus                                     3.1               46
# My Beautiful Bride                          4.8               45
# Volcanic UFO Mysteries                      6.0               45
# Bottom Feeders                              6.6               44
# Ape Canyon                                  5.8               44
# Hot Money                                   5.8               44
# Travis Turner                               3.6               44
# Nightingale: A Melody of Life               6.2               43
# The Believer                                3.8               43
# Kilroy                                      5.2               43
# Gun and a Hotel Bible                       6.6               42
# Axeman at Cutters Creek                     3.8               42
# Hampton's Legion                            1.9               42
# The Bid                                     4.1               41
# All We Got                                  5.3               40
# Good Grief It's Friday                      4.8               40
# The Healing Garden                          5.6               38
# Honesty Weekend                             4.7               38
# Virus Shark                                 1.9               38
# Magic Max                                   4.6               37
# Voyage of the Chimera                       3.8               37
# Love You Right: An R&B Musical              6.6               35
# Mummy Dearest                               2.4               34
# Aperture Kids and the Mysterious Neighbor   4.9               33
# Invincible                                  8.7               91

# %%
titles_p21 = len(p21_titles["Title"].unique())
titles_p21
# Out:
# 60

# %%
p_imdb_21 = p21_titles["IMDb"].mean()
p_imdb_19.round(1)
# Out:
# 5.9

# %%
p_top10_imdb_21 = p21_titles.sort_values("IMDb", ascending=False)
p_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                 Genres  IMDb  \
# Title
# Invincible                             Crime, Drama, Mystery, Thriller   8.7
# P!nk: All I Know So Far                    Documentary,Biography,Music   7.9
# Jathi Ratnalu                                                   Comedy   7.6
# Our Friend                                               Drama,Romance   7.3
# One Night in Miami...                                            Drama   7.1
# The Map of Tiny Perfect Things                  Comedy,Fantasy,Romance   6.8
# The Tomorrow War                Action,Adventure,Drama,Sci-Fi,Thriller   6.6
# Love You Right: An R&B Musical                   Drama,Musical,Romance   6.6
# Bottom Feeders                                                  Comedy   6.6
# Gun and a Hotel Bible                                            Drama   6.6
#
#                                 Rotten Tomatoes
# Title
# Invincible                                   91
# P!nk: All I Know So Far                      57
# Jathi Ratnalu                                61
# Our Friend                                   74
# One Night in Miami...                        86
# The Map of Tiny Perfect Things               69
# The Tomorrow War                             81
# Love You Right: An R&B Musical               35
# Bottom Feeders                               44
# Gun and a Hotel Bible                        42

# %%
p_rot_21 = p21_titles["Rotten Tomatoes"].mean()
p_rot_21.round(1)
# Out:
# 51.0

# %%
p_top10_rot_21 = p21_titles.sort_values("Rotten Tomatoes", ascending=False)
p_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                 Genres  IMDb  \
# Title
# Invincible                             Crime, Drama, Mystery, Thriller   8.7
# One Night in Miami...                                            Drama   7.1
# The Tomorrow War                Action,Adventure,Drama,Sci-Fi,Thriller   6.6
# Our Friend                                               Drama,Romance   7.3
# Coming 2 America                                                Comedy   5.3
# The Map of Tiny Perfect Things                  Comedy,Fantasy,Romance   6.8
# Tom Clancy's Without Remorse                       Action,Thriller,War   5.8
# Jolt                                                   Action,Thriller   5.5
# Awake                           Action,Adventure,Drama,Sci-Fi,Thriller   4.8
# Jathi Ratnalu                                                   Comedy   7.6
#
#                                 Rotten Tomatoes
# Title
# Invincible                                   91
# One Night in Miami...                        86
# The Tomorrow War                             81
# Our Friend                                   74
# Coming 2 America                             70
# The Map of Tiny Perfect Things               69
# Tom Clancy's Without Remorse                 69
# Jolt                                         67
# Awake                                        63
# Jathi Ratnalu                                61

# %%
# Netflix
n19 = Path("Resources/Netflix/n_19.csv")
n19_titles = pd.read_csv(n19)
n19_titles.set_index("Title")
# Out:
#                                                                      Genres  \
# Title
# The Irishman                                          Biography,Crime,Drama
# Article 15                                     Crime,Drama,Mystery,Thriller
# Dolemite Is My Name                                  Biography,Comedy,Drama
# Fyre                                                Documentary,Crime,Music
# The King                                Biography,Drama,History,Romance,War
# ...                                                                     ...
# Sin City                                                     Crime,Thriller
# After Maria                                               Documentary,Short
# Holy Expectations                                                    Comedy
# Grego Rossello: disculpe las molestias                               Comedy
# Love on the Spectrum                                          Comedy, Drama
#
#                                         IMDb  Rotten Tomatoes
# Title
# The Irishman                             7.8               98
# Article 15                               8.2               92
# Dolemite Is My Name                      7.3               92
# Fyre                                     7.2               91
# The King                                 7.2               90
# ...                                      ...              ...
# Sin City                                 3.6               32
# After Maria                              4.6               31
# Holy Expectations                        4.9               30
# Grego Rossello: disculpe las molestias   4.4               29
# Love on the Spectrum                     8.6               96
#
# [546 rows x 3 columns]

# %%
titles_n19 = len(n19_titles["Title"].unique())
titles_n19
# Out:
# 546

# %%
n_imdb_19 = n19_titles["IMDb"].mean()
n_imdb_19.round(1)
# Out:
# 6.2

# %%
n_top10_imdb_19 = n19_titles.sort_values("IMDb", ascending=False)
n_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                                                    Genres  \
# Title
# Rubaru Roshni                                                 Documentary
# Love on the Spectrum                                        Comedy, Drama
# K. D.                                        Crime,Drama,Mystery,Thriller
# Oththa Seruppu Size 7                                      Drama,Thriller
# Dave Chappelle: Sticks & Stones                                    Comedy
# Mallesham                                                       Biography
# Super Deluxe                                  Comedy,Crime,Drama,Thriller
# Dancing with the Birds                                        Documentary
# Hikaru Utada Laughter in the Dark Tour 2018                         Music
# A Truthful Mother                                               Animation
#
#                                              IMDb  Rotten Tomatoes
# Title
# Rubaru Roshni                                 8.8               56
# Love on the Spectrum                          8.6               96
# K. D.                                         8.6               59
# Oththa Seruppu Size 7                         8.5               61
# Dave Chappelle: Sticks & Stones               8.5               84
# Mallesham                                     8.4               55
# Super Deluxe                                  8.4               87
# Dancing with the Birds                        8.3               61
# Hikaru Utada Laughter in the Dark Tour 2018   8.3               47
# A Truthful Mother                             8.3               48

# %%
n_rot_19 = n19_titles["Rotten Tomatoes"].mean()
n_rot_19.round(1)
# Out:
# 53.7

# %%
n_top10_rot_19 = n19_titles.sort_values("Rotten Tomatoes", ascending=False)
n_top10_rot_19.set_index("Title").head(10)
# Out:
#                                                              Genres  IMDb  \
# Title
# The Irishman                                  Biography,Crime,Drama   7.8
# Love on the Spectrum                                  Comedy, Drama   8.6
# Dolemite Is My Name                          Biography,Comedy,Drama   7.3
# Article 15                             Crime,Drama,Mystery,Thriller   8.2
# Fyre                                        Documentary,Crime,Music   7.2
# The King                        Biography,Drama,History,Romance,War   7.2
# I Am Mother                           Drama,Mystery,Sci-Fi,Thriller   6.7
# Tell Me Who I Am                                     Drama,Thriller   7.6
# I Lost My Body                      Animation,Drama,Fantasy,Romance   7.6
# The Boy Who Harnessed the Wind              Biography,Drama,History   7.6
#
#                                 Rotten Tomatoes
# Title
# The Irishman                                 98
# Love on the Spectrum                         96
# Dolemite Is My Name                          92
# Article 15                                   92
# Fyre                                         91
# The King                                     90
# I Am Mother                                  89
# Tell Me Who I Am                             89
# I Lost My Body                               89
# The Boy Who Harnessed the Wind               89

# %%
n20 = Path("Resources/Netflix/n_20.csv")
n20_titles = pd.read_csv(n20)
n20_titles.set_index("Title")
# Out:
#                                                                Genres  IMDb  \
# Title
# David Attenborough: A Life on Our Planet        Documentary,Biography   9.0
# The Social Dilemma                                  Documentary,Drama   7.6
# The Trial of the Chicago 7                     Drama,History,Thriller   7.8
# Miss Americana                            Documentary,Biography,Music   7.4
# The Half of It                                   Comedy,Drama,Romance   6.9
# ...                                                               ...   ...
# True: Wuzzle Wegg Day                                       Animation   7.1
# An Unremarkable Christmas                                Comedy,Drama   3.3
# Asuraguru                                       Action,Crime,Thriller   3.3
# One Like It                                      Comedy,Music,Romance   5.8
# Small Chops                                                     Drama   3.1
#
#                                           Rotten Tomatoes
# Title
# David Attenborough: A Life on Our Planet               95
# The Social Dilemma                                     93
# The Trial of the Chicago 7                             92
# Miss Americana                                         90
# The Half of It                                         89
# ...                                                   ...
# True: Wuzzle Wegg Day                                  33
# An Unremarkable Christmas                              33
# Asuraguru                                              32
# One Like It                                            32
# Small Chops                                            31
#
# [452 rows x 3 columns]

# %%
titles_n20 = len(n20_titles["Title"].unique())
titles_n20
# Out:
# 452

# %%
n_imdb_20 = n20_titles["IMDb"].mean()
n_imdb_20.round(1)
# Out:
# 6.0

# %%
n_top10_imdb_20 = n20_titles.sort_values("IMDb", ascending=False)
n_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                                                    Genres  \
# Title
# David Attenborough: A Life on Our Planet            Documentary,Biography
# Sky Tour: The Movie                                     Documentary,Music
# Best Wishes, Warmest Regards: A Schitt's Creek ...                    NaN
# Emicida: AmarElo - It's All for Yesterday               Documentary,Music
# Ben Platt: Live from Radio City Music Hall                          Music
# Kiss the Ground                                               Documentary
# Disclosure                                                 Drama,Thriller
# The Three Deaths of Marisela Escobedo                   Documentary,Crime
# Rising Phoenix                                          Documentary,Sport
# My Octopus Teacher                                            Documentary
#
#                                                     IMDb  Rotten Tomatoes
# Title
# David Attenborough: A Life on Our Planet             9.0               95
# Sky Tour: The Movie                                  8.7               58
# Best Wishes, Warmest Regards: A Schitt's Creek ...   8.6               61
# Emicida: AmarElo - It's All for Yesterday            8.5               67
# Ben Platt: Live from Radio City Music Hall           8.4               57
# Kiss the Ground                                      8.3               87
# Disclosure                                           8.2               69
# The Three Deaths of Marisela Escobedo                8.2               62
# Rising Phoenix                                       8.1               67
# My Octopus Teacher                                   8.1               83

# %%
n_rot_20 = n20_titles["Rotten Tomatoes"].mean()
n_rot_20.round(1)
# Out:
# 53.7

# %%
n_top10_rot_20 = n20_titles.sort_values("Rotten Tomatoes", ascending=False)
n_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                                Genres  IMDb  \
# Title
# David Attenborough: A Life on Our Planet        Documentary,Biography   9.0
# The Social Dilemma                                  Documentary,Drama   7.6
# The Trial of the Chicago 7                     Drama,History,Thriller   7.8
# Miss Americana                            Documentary,Biography,Music   7.4
# The Half of It                                   Comedy,Drama,Romance   6.9
# The Devil All the Time                           Crime,Drama,Thriller   7.1
# Pieces of a Woman                                               Drama   7.1
# Kiss the Ground                                           Documentary   8.3
# Crip Camp: A Disability Revolution                Documentary,History   7.7
# Extraction                                            Action,Thriller   6.7
#
#                                           Rotten Tomatoes
# Title
# David Attenborough: A Life on Our Planet               95
# The Social Dilemma                                     93
# The Trial of the Chicago 7                             92
# Miss Americana                                         90
# The Half of It                                         89
# The Devil All the Time                                 89
# Pieces of a Woman                                      88
# Kiss the Ground                                        87
# Crip Camp: A Disability Revolution                     87
# Extraction                                             87

# %%
n21 = Path("Resources/Netflix/n_21.csv")
n21_titles = pd.read_csv(n21)
n21_titles.set_index("Title")
# Out:
#                                                                      Genres  \
# Title
# Bo Burnham: Inside                                       Comedy,Drama,Music
# The Dig                                             Biography,Drama,History
# Army of the Dead                        Action,Crime,Horror,Sci-Fi,Thriller
# The White Tiger                                                 Crime,Drama
# I Care a Lot                                          Comedy,Crime,Thriller
# ...                                                                     ...
# RebellComedy: Straight Outta the Zoo                                 Comedy
# Sanitation Day                                                     Thriller
# The Last Mercenary                                            Action,Comedy
# Nine Perfect Strangers                                        Drama, Sci-Fi
# He-Man and the Masters of the Universe                      Comedy, Musical
#
#                                         IMDb  Rotten Tomatoes
# Title
# Bo Burnham: Inside                       8.8               81
# The Dig                                  7.1               75
# Army of the Dead                         5.8               75
# The White Tiger                          7.1               75
# I Care a Lot                             6.3               74
# ...                                      ...              ...
# RebellComedy: Straight Outta the Zoo     4.7               36
# Sanitation Day                           3.8               34
# The Last Mercenary                       5.9               23
# Nine Perfect Strangers                   7.1               95
# He-Man and the Masters of the Universe   6.2               77
#
# [191 rows x 3 columns]

# %%
titles_n21 = len(n21_titles["Title"].unique())
titles_n21
# Out:
# 191

# %%
n_imdb_21 = n21_titles["IMDb"].mean()
n_imdb_21.round(1)
# Out:
# 6.1

# %%
n_top10_imdb_21 = n21_titles.sort_values("IMDb", ascending=False)
n_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                Genres  IMDb  \
# Title
# 7 Yards: The Chris Norton Story                           Documentary   8.9
# In Our Mothers' Gardens                                   Documentary   8.9
# Bo Burnham: Inside                                 Comedy,Drama,Music   8.8
# Mandela                                                  Comedy,Drama   8.5
# Mimi                                                     Comedy,Drama   8.4
# Seaspiracy                                      Documentary,Adventure   8.2
# Ashin of the North               Action,Drama,History,Horror,Thriller   8.2
# Nayattu                                                      Thriller   8.2
# Rurouni Kenshin: The Beginning                 Action,Adventure,Drama   8.0
# Cinema Bandi                                             Comedy,Drama   8.0
#
#                                  Rotten Tomatoes
# Title
# 7 Yards: The Chris Norton Story               51
# In Our Mothers' Gardens                       54
# Bo Burnham: Inside                            81
# Mandela                                       61
# Mimi                                          64
# Seaspiracy                                    67
# Ashin of the North                            58
# Nayattu                                       61
# Rurouni Kenshin: The Beginning                55
# Cinema Bandi                                  60

# %%
n_rot_21 = n21_titles["Rotten Tomatoes"].mean()
n_rot_21.round(1)
# Out:
# 55.7

# %%
n_top10_rot_21 = n21_titles.sort_values("Rotten Tomatoes", ascending=False)
n_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                            Genres  \
# Title
# Nine Perfect Strangers                                              Drama, Sci-Fi
# Bo Burnham: Inside                                             Comedy,Drama,Music
# He-Man and the Masters of the Universe                            Comedy, Musical
# The White Tiger                                                       Crime,Drama
# The Dig                                                   Biography,Drama,History
# Army of the Dead                              Action,Crime,Horror,Sci-Fi,Thriller
# I Care a Lot                                                Comedy,Crime,Thriller
# Fear Street Part Two: 1978                                   Drama,Horror,Mystery
# Wish Dragon                             Animation,Adventure,Comedy,Family,Fantasy
# The Mitchells vs. The Machines                                   Comedy,Talk-Show
#
#                                         IMDb  Rotten Tomatoes
# Title
# Nine Perfect Strangers                   7.1               95
# Bo Burnham: Inside                       8.8               81
# He-Man and the Masters of the Universe   6.2               77
# The White Tiger                          7.1               75
# The Dig                                  7.1               75
# Army of the Dead                         5.8               75
# I Care a Lot                             6.3               74
# Fear Street Part Two: 1978               6.8               73
# Wish Dragon                              7.2               73
# The Mitchells vs. The Machines           7.7               73

# %%
# Disney+
d19 = Path("Resources/Disney/d_19.csv")
d19_titles = pd.read_csv(d19)
d19_titles.set_index("Title")
# Out:
#                                                                                                Genres  \
# Title
# The Kid                                                                       Biography,Drama,Western
# Teen Spirit                                                                               Drama,Music
# The Flood                                                                 Action,Crime,Drama,Thriller
# Pinocchio                                                      Animation,Drama,Family,Fantasy,Musical
# Avengers: Endgame                                                       Action,Adventure,Drama,Sci-Fi
# Toy Story 4                                                 Animation,Adventure,Comedy,Family,Fantasy
# Captain Marvel                                                                Action,Adventure,Sci-Fi
# Star Wars: The Rise of Skywalker                                      Action,Adventure,Fantasy,Sci-Fi
# Frozen II                                           Animation,Adventure,Comedy,Family,Fantasy,Musical
# Togo                                                         Adventure,Biography,Drama,Family,History
# Maleficent: Mistress of Evil                                                 Adventure,Family,Fantasy
# Descendants 3                                          Action,Adventure,Drama,Family,Musical,Thriller
# The Kid Who Would Be King                                             Action,Adventure,Family,Fantasy
# Kitbull                                                                  Animation,Short,Drama,Family
# Float                                                            Animation,Short,Drama,Family,Fantasy
# Purl                                                                    Animation,Short,Comedy,Family
# Smash and Grab                                                                            Crime,Drama
# Penguins                                                                           Documentary,Family
# Apollo: Missions to the Moon                                                      Documentary,History
# The Little Mermaid Live!                                               Family,Fantasy,Musical,Romance
# Into the Grand Canyon                                                                     Documentary
# Forky Asks a Question: What Is a Friend?                        Animation,Short,Comedy,Family,Fantasy
# Marvel Studios: Expanding the Universe                                              Documentary,Short
# Expedition Amelia                                                                 Documentary,History
# Forky Asks a Question: What Is Love?                            Animation,Short,Comedy,Family,Fantasy
# High School Musical: The Musical: The Series: T...                                        Documentary
# Forky Asks a Question: What Is Money?                           Animation,Short,Comedy,Family,Fantasy
# Forky Asks a Question: What Is Time?                            Animation,Short,Comedy,Family,Fantasy
# Marvel Rising: Chasing Ghosts                                 Animation,Short,Action,Adventure,Family
# Forky Asks a Question: What Is Art?                             Animation,Short,Comedy,Family,Fantasy
# Forky Asks a Question: What Is a Computer?                      Animation,Short,Comedy,Family,Fantasy
# Marvel Rising: Heart of Iron                                  Animation,Short,Action,Adventure,Sci-Fi
# Okavango: River of Dreams                                                                 Documentary
# Forky Asks a Question: What Is a Leader?                        Animation,Short,Comedy,Family,Fantasy
# The Lost Tomb of Alexander the Great                                                      Documentary
# Marvel Rising: Battle of the Bands                            Animation,Short,Action,Adventure,Family
# Forky Asks a Question: What Is a Pet?                           Animation,Short,Comedy,Family,Fantasy
# Marvel Rising: Playing with Fire                       Animation,Short,Action,Adventure,Family,Sci-Fi
# Pompeii: Secrets of the Dead                                                                  History
# Marvel Rising: Operation Shuri                                       Animation,Short,Action,Adventure
# Star Wars: Galaxy's Edge - Adventure Awaits                                               Documentary
# Notre Dame: Race Against the Inferno                                          Documentary,Short,Drama
# Viking Warrior Women                                                        Documentary,Drama,History
# Chasing the Equinox                                                                       Documentary
# Arendelle Castle Yule Log                                                                   Animation
# Man vs. Shark                                                                             Documentary
# The Lost City of Machu Picchu                                                     Documentary,History
#
#                                                     IMDb  Rotten Tomatoes
# Title
# The Kid                                              5.9               62
# Teen Spirit                                          6.1               60
# The Flood                                            5.4               50
# Pinocchio                                            6.2               72
# Avengers: Endgame                                    8.4               90
# Toy Story 4                                          7.7               82
# Captain Marvel                                       6.8               81
# Star Wars: The Rise of Skywalker                     6.5               78
# Frozen II                                            6.8               78
# Togo                                                 8.0               76
# Maleficent: Mistress of Evil                         6.6               76
# Descendants 3                                        6.6               67
# The Kid Who Would Be King                            6.0               64
# Kitbull                                              8.0               64
# Float                                                7.3               60
# Purl                                                 6.5               58
# Smash and Grab                                       6.7               56
# Penguins                                             7.1               56
# Apollo: Missions to the Moon                         7.6               53
# The Little Mermaid Live!                             5.6               53
# Into the Grand Canyon                                7.4               52
# Forky Asks a Question: What Is a Friend?             7.1               51
# Marvel Studios: Expanding the Universe               6.8               50
# Expedition Amelia                                    7.2               49
# Forky Asks a Question: What Is Love?                 7.4               49
# High School Musical: The Musical: The Series: T...   7.2               49
# Forky Asks a Question: What Is Money?                6.4               48
# Forky Asks a Question: What Is Time?                 6.8               48
# Marvel Rising: Chasing Ghosts                        4.9               47
# Forky Asks a Question: What Is Art?                  6.5               47
# Forky Asks a Question: What Is a Computer?           6.6               47
# Marvel Rising: Heart of Iron                         4.4               47
# Okavango: River of Dreams                            8.3               47
# Forky Asks a Question: What Is a Leader?             6.5               46
# The Lost Tomb of Alexander the Great                 6.6               46
# Marvel Rising: Battle of the Bands                   5.0               45
# Forky Asks a Question: What Is a Pet?                6.3               45
# Marvel Rising: Playing with Fire                     5.2               45
# Pompeii: Secrets of the Dead                         6.8               44
# Marvel Rising: Operation Shuri                       4.8               44
# Star Wars: Galaxy's Edge - Adventure Awaits          5.4               44
# Notre Dame: Race Against the Inferno                 6.4               43
# Viking Warrior Women                                 6.5               39
# Chasing the Equinox                                  6.3               38
# Arendelle Castle Yule Log                            5.5               38
# Man vs. Shark                                        6.0               38
# The Lost City of Machu Picchu                        7.1               38

# %%
titles_d19 = len(d19_titles["Title"].unique())
titles_d19
# Out:
# 47

# %%
d_imdb_19 = d19_titles["IMDb"].mean()
d_imdb_19.round(1)
# Out:
# 6.5

# %%
d_top10_imdb_19 = d19_titles.sort_values("IMDb", ascending=False)
d_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                                                          Genres  \
# Title
# Avengers: Endgame                                 Action,Adventure,Drama,Sci-Fi
# Okavango: River of Dreams                                           Documentary
# Kitbull                                            Animation,Short,Drama,Family
# Togo                                   Adventure,Biography,Drama,Family,History
# Toy Story 4                           Animation,Adventure,Comedy,Family,Fantasy
# Apollo: Missions to the Moon                                Documentary,History
# Forky Asks a Question: What Is Love?      Animation,Short,Comedy,Family,Fantasy
# Into the Grand Canyon                                               Documentary
# Float                                      Animation,Short,Drama,Family,Fantasy
# Expedition Amelia                                           Documentary,History
#
#                                       IMDb  Rotten Tomatoes
# Title
# Avengers: Endgame                      8.4               90
# Okavango: River of Dreams              8.3               47
# Kitbull                                8.0               64
# Togo                                   8.0               76
# Toy Story 4                            7.7               82
# Apollo: Missions to the Moon           7.6               53
# Forky Asks a Question: What Is Love?   7.4               49
# Into the Grand Canyon                  7.4               52
# Float                                  7.3               60
# Expedition Amelia                      7.2               49

# %%
d_rot_19 = d19_titles["Rotten Tomatoes"].mean()
d_rot_19.round(1)
# Out:
# 54.5

# %%
d_top10_rot_19 = d19_titles.sort_values("Rotten Tomatoes", ascending=False)
d_top10_rot_19.set_index("Title").head(10)
# Out:
#                                                                              Genres  \
# Title
# Avengers: Endgame                                     Action,Adventure,Drama,Sci-Fi
# Toy Story 4                               Animation,Adventure,Comedy,Family,Fantasy
# Captain Marvel                                              Action,Adventure,Sci-Fi
# Star Wars: The Rise of Skywalker                    Action,Adventure,Fantasy,Sci-Fi
# Frozen II                         Animation,Adventure,Comedy,Family,Fantasy,Musical
# Togo                                       Adventure,Biography,Drama,Family,History
# Maleficent: Mistress of Evil                               Adventure,Family,Fantasy
# Pinocchio                                    Animation,Drama,Family,Fantasy,Musical
# Descendants 3                        Action,Adventure,Drama,Family,Musical,Thriller
# The Kid Who Would Be King                           Action,Adventure,Family,Fantasy
#
#                                   IMDb  Rotten Tomatoes
# Title
# Avengers: Endgame                  8.4               90
# Toy Story 4                        7.7               82
# Captain Marvel                     6.8               81
# Star Wars: The Rise of Skywalker   6.5               78
# Frozen II                          6.8               78
# Togo                               8.0               76
# Maleficent: Mistress of Evil       6.6               76
# Pinocchio                          6.2               72
# Descendants 3                      6.6               67
# The Kid Who Would Be King          6.0               64

# %%
d20 = Path("Resources/Disney/d_20.csv")
d20_titles = pd.read_csv(d20)
d20_titles.set_index("Title")
# Out:
#                                                                                              Genres  \
# Title
# Sky High                                                             Adventure,Comedy,Family,Sci-Fi
# Soul                                                Animation,Adventure,Comedy,Family,Fantasy,Music
# Hamilton                                                            Biography,Drama,History,Musical
# Onward                                                    Animation,Adventure,Comedy,Family,Fantasy
# Black Is King                                                         Adventure,Drama,Fantasy,Music
# ...                                                                                             ...
# Disney Holiday Magic Quest                                                              Documentary
# India's Wild Leopards                                                             Documentary,Short
# Disney Channel Halloween House Party                                          Comedy,Family,Musical
# Challenge Accepted! Disney Channel's Epic Holid...                                          Musical
# Sharks of the Bermuda Triangle                                                          Documentary
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Sky High                                             5.6               51
# Soul                                                 8.1               89
# Hamilton                                             8.4               81
# Onward                                               7.4               80
# Black Is King                                        5.7               79
# ...                                                  ...              ...
# Disney Holiday Magic Quest                           6.2               35
# India's Wild Leopards                                7.8               35
# Disney Channel Halloween House Party                 5.3               33
# Challenge Accepted! Disney Channel's Epic Holid...   3.9               32
# Sharks of the Bermuda Triangle                       6.5               31
#
# [62 rows x 3 columns]

# %%
titles_d20 = len(d20_titles["Title"].unique())
titles_d20
# Out:
# 62

# %%
d_imdb_20 = d20_titles["IMDb"].mean()
d_imdb_20.round(1)
# Out:
# 6.6

# %%
d_top10_imdb_20 = d20_titles.sort_values("IMDb", ascending=False)
d_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                                                                       Genres  \
# Title
# Hamilton                                                     Biography,Drama,History,Musical
# Folklore: The Long Pond Studio Sessions                              Documentary,Drama,Music
# Soul                                         Animation,Adventure,Comedy,Family,Fantasy,Music
# Jane Goodall: The Hope                                                           Documentary
# India's Wild Leopards                                                      Documentary,Short
# Born Wild: The Next Generation                                                   Documentary
# Miraculous World: New York, United HeroeZ  Animation,Action,Adventure,Family,Fantasy,Romance
# Surviving the Mount St. Helens Disaster                                  Documentary,History
# From Our Family to Yours                                              Animation,Short,Family
# Out                                        Animation,Short,Comedy,Drama,Family,Fantasy,Ro...
#
#                                            IMDb  Rotten Tomatoes
# Title
# Hamilton                                    8.4               81
# Folklore: The Long Pond Studio Sessions     8.4               64
# Soul                                        8.1               89
# Jane Goodall: The Hope                      7.9               49
# India's Wild Leopards                       7.8               35
# Born Wild: The Next Generation              7.7               38
# Miraculous World: New York, United HeroeZ   7.7               60
# Surviving the Mount St. Helens Disaster     7.6               42
# From Our Family to Yours                    7.6               42
# Out                                         7.5               57

# %%
d_rot_20 = d20_titles["Rotten Tomatoes"].mean()
d_rot_20.round(1)
# Out:
# 51.0

# %%
d_top10_rot_20 = d20_titles.sort_values("Rotten Tomatoes", ascending=False)
d_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                                                                Genres  \
# Title
# Soul                                                  Animation,Adventure,Comedy,Family,Fantasy,Music
# Hamilton                                                              Biography,Drama,History,Musical
# Onward                                                      Animation,Adventure,Comedy,Family,Fantasy
# Black Is King                                                           Adventure,Drama,Fantasy,Music
# Stargirl                                                  Action,Adventure,Crime,Drama,Fantasy,Sci-Fi
# Timmy Failure: Mistakes Were Made                               Adventure,Comedy,Drama,Family,Fantasy
# The One and Only Ivan                                           Adventure,Comedy,Drama,Family,Fantasy
# Folklore: The Long Pond Studio Sessions                                       Documentary,Drama,Music
# Phineas and Ferb: The Movie: Candace Against th...  Animation,Action,Adventure,Comedy,Family,Fanta...
# Godmothered                                                               Comedy,Drama,Family,Fantasy
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Soul                                                 8.1               89
# Hamilton                                             8.4               81
# Onward                                               7.4               80
# Black Is King                                        5.7               79
# Stargirl                                             6.2               74
# Timmy Failure: Mistakes Were Made                    6.1               73
# The One and Only Ivan                                6.6               67
# Folklore: The Long Pond Studio Sessions              8.4               64
# Phineas and Ferb: The Movie: Candace Against th...   7.2               63
# Godmothered                                          6.1               63

# %%
d21 = Path("Resources/Disney/d_21.csv")
d21_titles = pd.read_csv(d21)
d21_titles.set_index("Title")
# Out:
#                                                                                                Genres  \
# Title
# Luca                                                        Animation,Adventure,Comedy,Family,Fantasy
# Raya and the Last Dragon                             Animation,Action,Adventure,Comedy,Family,Fantasy
# 22 vs. Earth                                          Animation,Short,Adventure,Comedy,Family,Fantasy
# The Simpsons: The Good, the Bart, and the Loki                   Animation,Short,Action,Comedy,Family
# Us Again                                                         Animation,Short,Drama,Family,Musical
# Flora & Ulysses                                                               Adventure,Comedy,Family
# Miraculous World: Shanghai – The Legend of Lady...  Animation,Action,Adventure,Family,Fantasy,Romance
# Maggie Simpson in The Force Awakens from Its Nap                 Animation,Short,Comedy,Family,Sci-Fi
# Stuntman                                                                                  Documentary
# The Little Prince(ss)                                                                     Short,Drama
# Wolfgang                                                                        Documentary,Biography
# Star Wars Biomes                                                                         Short,Sci-Fi
# Shark Beach with Chris Hemsworth                                                          Documentary
# Playing with Sharks: The Valerie Taylor Story                                   Documentary,Adventure
# Marvel's Behind the Mask                                                                  Documentary
# American Eid                                                                              Short,Drama
# Let's Be Tigers                                                                           Short,Drama
# Growing Fangs                                                                                   Short
# Orca Vs Great White                                                                       Documentary
# The Last of the Chupacabras                                                               Short,Drama
# Dinner Is Served                                                                         Short,Horror
# Rogue Shark?                                                                              Documentary
# Own the Room                                                                              Documentary
# Shark Gangs                                                                               Documentary
# My Music Story: Yoshiki                                                             Documentary,Music
# Monsters at Work                                                           Adventure, Drama, Thriller
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Luca                                                 7.5               82
# Raya and the Last Dragon                             7.4               81
# 22 vs. Earth                                         6.5               64
# The Simpsons: The Good, the Bart, and the Loki       6.1               64
# Us Again                                             7.9               64
# Flora & Ulysses                                      6.3               62
# Miraculous World: Shanghai – The Legend of Lady...   7.6               62
# Maggie Simpson in The Force Awakens from Its Nap     6.2               61
# Stuntman                                             7.1               56
# The Little Prince(ss)                                7.5               56
# Wolfgang                                             7.0               54
# Star Wars Biomes                                     6.7               54
# Shark Beach with Chris Hemsworth                     6.8               53
# Playing with Sharks: The Valerie Taylor Story        7.8               53
# Marvel's Behind the Mask                             6.4               53
# American Eid                                         7.4               52
# Let's Be Tigers                                      7.2               51
# Growing Fangs                                        6.5               49
# Orca Vs Great White                                  5.6               49
# The Last of the Chupacabras                          6.4               48
# Dinner Is Served                                     6.1               48
# Rogue Shark?                                         7.2               47
# Own the Room                                         6.4               46
# Shark Gangs                                          6.8               45
# My Music Story: Yoshiki                              7.3               33
# Monsters at Work                                     7.1               82

# %%
titles_d21 = len(d21_titles["Title"].unique())
titles_d21
# Out:
# 26

# %%
d_imdb_21 = d21_titles["IMDb"].mean()
d_imdb_21.round(1)
# Out:
# 6.9

# %%
d_top10_imdb_21 = d21_titles.sort_values("IMDb", ascending=False)
d_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                                                Genres  \
# Title
# Us Again                                                         Animation,Short,Drama,Family,Musical
# Playing with Sharks: The Valerie Taylor Story                                   Documentary,Adventure
# Miraculous World: Shanghai – The Legend of Lady...  Animation,Action,Adventure,Family,Fantasy,Romance
# The Little Prince(ss)                                                                     Short,Drama
# Luca                                                        Animation,Adventure,Comedy,Family,Fantasy
# American Eid                                                                              Short,Drama
# Raya and the Last Dragon                             Animation,Action,Adventure,Comedy,Family,Fantasy
# My Music Story: Yoshiki                                                             Documentary,Music
# Rogue Shark?                                                                              Documentary
# Let's Be Tigers                                                                           Short,Drama
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Us Again                                             7.9               64
# Playing with Sharks: The Valerie Taylor Story        7.8               53
# Miraculous World: Shanghai – The Legend of Lady...   7.6               62
# The Little Prince(ss)                                7.5               56
# Luca                                                 7.5               82
# American Eid                                         7.4               52
# Raya and the Last Dragon                             7.4               81
# My Music Story: Yoshiki                              7.3               33
# Rogue Shark?                                         7.2               47
# Let's Be Tigers                                      7.2               51

# %%
d_rot_21 = d21_titles["Rotten Tomatoes"].mean()
d_rot_21.round(1)
# Out:
# 56.5

# %%
d_top10_rot_21 = d21_titles.sort_values("Rotten Tomatoes", ascending=False)
d_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                                                Genres  \
# Title
# Luca                                                        Animation,Adventure,Comedy,Family,Fantasy
# Monsters at Work                                                           Adventure, Drama, Thriller
# Raya and the Last Dragon                             Animation,Action,Adventure,Comedy,Family,Fantasy
# 22 vs. Earth                                          Animation,Short,Adventure,Comedy,Family,Fantasy
# Us Again                                                         Animation,Short,Drama,Family,Musical
# The Simpsons: The Good, the Bart, and the Loki                   Animation,Short,Action,Comedy,Family
# Flora & Ulysses                                                               Adventure,Comedy,Family
# Miraculous World: Shanghai – The Legend of Lady...  Animation,Action,Adventure,Family,Fantasy,Romance
# Maggie Simpson in The Force Awakens from Its Nap                 Animation,Short,Comedy,Family,Sci-Fi
# Stuntman                                                                                  Documentary
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Luca                                                 7.5               82
# Monsters at Work                                     7.1               82
# Raya and the Last Dragon                             7.4               81
# 22 vs. Earth                                         6.5               64
# Us Again                                             7.9               64
# The Simpsons: The Good, the Bart, and the Loki       6.1               64
# Flora & Ulysses                                      6.3               62
# Miraculous World: Shanghai – The Legend of Lady...   7.6               62
# Maggie Simpson in The Force Awakens from Its Nap     6.2               61
# Stuntman                                             7.1               56

# %%
hb19 = Path("Resources/HBO/hb_19.csv")
hb19_titles = pd.read_csv(hb19)
hb19_titles.set_index("Title")
# Out:
#                                   Genres  IMDb  Rotten Tomatoes
# Title
# Chernobyl                          Drama   9.4               96
# Watchmen                          Action   8.1               95
# Euphoria                           Drama   8.3               82
# Doom Patrol                       Action   8.0               95
# His Dark Materials             Adventure   7.9               80
# Years and Years                    Drama   8.4               89
# Primal                         Animation   8.7              100
# Gentleman Jack                     Drama   8.2               90
# The Righteous Gemstones           Comedy   8.1               75
# Mrs. Fletcher                     Comedy   7.0               84
# Our Boys                           Drama   7.4               93
# Batwoman                          Action   3.6               79
# Nancy Drew                         Drama   6.0               53
# Los Espookys                      Comedy   7.5              100
# Ghosts                            Comedy   7.8              100
# A Black Lady Sketch Show          Comedy   7.1              100
# The Movies                   Documentary   7.8               67
# The Case Against Adnan Syed  Documentary   6.6               82

# %%
titles_hb19 = len(hb19_titles["Title"].unique())
titles_hb19
# Out:
# 18

# %%
hb_imdb_19 = hb19_titles["IMDb"].mean()
hb_imdb_19.round(1)
# Out:
# 7.6

# %%
hb_top10_imdb_19 = hb19_titles.sort_values("IMDb", ascending=False)
hb_top10_imdb_19.set_index("Title").head(10)
# Out:
#                             Genres  IMDb  Rotten Tomatoes
# Title
# Chernobyl                    Drama   9.4               96
# Primal                   Animation   8.7              100
# Years and Years              Drama   8.4               89
# Euphoria                     Drama   8.3               82
# Gentleman Jack               Drama   8.2               90
# The Righteous Gemstones     Comedy   8.1               75
# Watchmen                    Action   8.1               95
# Doom Patrol                 Action   8.0               95
# His Dark Materials       Adventure   7.9               80
# Ghosts                      Comedy   7.8              100

# %%
hb_rot_19 = hb19_titles["Rotten Tomatoes"].mean()
hb_rot_19.round(1)
# Out:
# 86.7

# %%
hb_top10_rot_19 = hb19_titles.sort_values("Rotten Tomatoes", ascending=False)
hb_top10_rot_19.set_index("Title").head(10)
# Out:
#                              Genres  IMDb  Rotten Tomatoes
# Title
# A Black Lady Sketch Show     Comedy   7.1              100
# Ghosts                       Comedy   7.8              100
# Primal                    Animation   8.7              100
# Los Espookys                 Comedy   7.5              100
# Chernobyl                     Drama   9.4               96
# Doom Patrol                  Action   8.0               95
# Watchmen                     Action   8.1               95
# Our Boys                      Drama   7.4               93
# Gentleman Jack                Drama   8.2               90
# Years and Years               Drama   8.4               89

# %%
hb20 = Path("Resources/HBO/hb_20.csv")
hb20_titles = pd.read_csv(hb20)
hb20_titles.set_index("Title")
# Out:
#                                                         Genres   HBO  IMDb  \
# Title
# The Outsider                                             Crime  True   7.9
# I Know This Much Is True                                 Drama  True   8.2
# The Plot Against America                                 Drama  True   7.3
# Legendary                                              Reality  True   7.1
# McMillion$                                         Documentary  True   7.2
# We're Here                                             Reality  True   8.0
# Perry Mason                                              Crime  True   7.2
# Love Life                                               Comedy  True   7.4
# RUN                                                    Mystery  True   6.3
# The New Pope                                             Drama  True   8.2
# Avenue 5                                                Comedy  True   6.4
# Looney Tunes Cartoons                                Animation  True   8.3
# Atlanta's Missing and Murdered: The Lost Children  Documentary  True   7.2
# Lovecraft Country                                        Drama  True   7.1
# The Not Too Late Show with Elmo                         Comedy  True   7.8
# Katy Keene                                              Comedy  True   6.1
# Trigonometry                                            Comedy  True   6.6
# Craftopia                                                Drama  True   6.0
#
#                                                    Rotten Tomatoes  \
# Title
# The Outsider                                                    82
# I Know This Much Is True                                        73
# The Plot Against America                                        86
# Legendary                                                       92
# McMillion$                                                      88
# We're Here                                                     100
# Perry Mason                                                     80
# Love Life                                                       59
# RUN                                                             82
# The New Pope                                                    90
# Avenue 5                                                        66
# Looney Tunes Cartoons                                           88
# Atlanta's Missing and Murdered: The Lost Children               94
# Lovecraft Country                                               96
# The Not Too Late Show with Elmo                                 80
# Katy Keene                                                      90
# Trigonometry                                                    80
# Craftopia                                                       83
#
#                                                                         _id
# Title
# The Outsider                                       6167a31d8a2fde8299a3937e
# I Know This Much Is True                           6167a31d8a2fde8299a39395
# The Plot Against America                           6167a31d8a2fde8299a393a7
# Legendary                                          6167a31d8a2fde8299a393b0
# McMillion$                                         6167a31d8a2fde8299a393b1
# We're Here                                         6167a31d8a2fde8299a393b2
# Perry Mason                                        6167a31d8a2fde8299a393b3
# Love Life                                          6167a31d8a2fde8299a393b4
# RUN                                                6167a31d8a2fde8299a393bc
# The New Pope                                       6167a31d8a2fde8299a393bd
# Avenue 5                                           6167a31d8a2fde8299a393bf
# Looney Tunes Cartoons                              6167a31d8a2fde8299a393c0
# Atlanta's Missing and Murdered: The Lost Children  6167a31d8a2fde8299a393cb
# Lovecraft Country                                  6167a31d8a2fde8299a393d3
# The Not Too Late Show with Elmo                    6167a31d8a2fde8299a393d9
# Katy Keene                                         6167a31d8a2fde8299a393e6
# Trigonometry                                       6167a31d8a2fde8299a393ee
# Craftopia                                          6167a31d8a2fde8299a393ef

# %%
titles_hb20 = len(hb20_titles["Title"].unique())
titles_hb20
# Out:
# 18

# %%
hb_imdb_20 = hb20_titles["IMDb"].mean()
hb_imdb_19.round(1)
# Out:
# 7.6

# %%
hb_top10_imdb_20 = hb20_titles.sort_values("IMDb", ascending=False)
hb_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                       Genres   HBO  IMDb  Rotten Tomatoes  \
# Title
# Looney Tunes Cartoons              Animation  True   8.3               88
# The New Pope                           Drama  True   8.2               90
# I Know This Much Is True               Drama  True   8.2               73
# We're Here                           Reality  True   8.0              100
# The Outsider                           Crime  True   7.9               82
# The Not Too Late Show with Elmo       Comedy  True   7.8               80
# Love Life                             Comedy  True   7.4               59
# The Plot Against America               Drama  True   7.3               86
# McMillion$                       Documentary  True   7.2               88
# Perry Mason                            Crime  True   7.2               80
#
#                                                       _id
# Title
# Looney Tunes Cartoons            6167a31d8a2fde8299a393c0
# The New Pope                     6167a31d8a2fde8299a393bd
# I Know This Much Is True         6167a31d8a2fde8299a39395
# We're Here                       6167a31d8a2fde8299a393b2
# The Outsider                     6167a31d8a2fde8299a3937e
# The Not Too Late Show with Elmo  6167a31d8a2fde8299a393d9
# Love Life                        6167a31d8a2fde8299a393b4
# The Plot Against America         6167a31d8a2fde8299a393a7
# McMillion$                       6167a31d8a2fde8299a393b1
# Perry Mason                      6167a31d8a2fde8299a393b3

# %%
hb_rot_20 = hb20_titles["Rotten Tomatoes"].mean()
hb_rot_20.round(1)
# Out:
# 83.8

# %%
hb_top10_rot_20 = hb20_titles.sort_values("Rotten Tomatoes", ascending=False)
hb_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                         Genres   HBO  IMDb  \
# Title
# We're Here                                             Reality  True   8.0
# Lovecraft Country                                        Drama  True   7.1
# Atlanta's Missing and Murdered: The Lost Children  Documentary  True   7.2
# Legendary                                              Reality  True   7.1
# The New Pope                                             Drama  True   8.2
# Katy Keene                                              Comedy  True   6.1
# Looney Tunes Cartoons                                Animation  True   8.3
# McMillion$                                         Documentary  True   7.2
# The Plot Against America                                 Drama  True   7.3
# Craftopia                                                Drama  True   6.0
#
#                                                    Rotten Tomatoes  \
# Title
# We're Here                                                     100
# Lovecraft Country                                               96
# Atlanta's Missing and Murdered: The Lost Children               94
# Legendary                                                       92
# The New Pope                                                    90
# Katy Keene                                                      90
# Looney Tunes Cartoons                                           88
# McMillion$                                                      88
# The Plot Against America                                        86
# Craftopia                                                       83
#
#                                                                         _id
# Title
# We're Here                                         6167a31d8a2fde8299a393b2
# Lovecraft Country                                  6167a31d8a2fde8299a393d3
# Atlanta's Missing and Murdered: The Lost Children  6167a31d8a2fde8299a393cb
# Legendary                                          6167a31d8a2fde8299a393b0
# The New Pope                                       6167a31d8a2fde8299a393bd
# Katy Keene                                         6167a31d8a2fde8299a393e6
# Looney Tunes Cartoons                              6167a31d8a2fde8299a393c0
# McMillion$                                         6167a31d8a2fde8299a393b1
# The Plot Against America                           6167a31d8a2fde8299a393a7
# Craftopia                                          6167a31d8a2fde8299a393ef

# %%
hb21 = Path("Resources/HBO/hb_21.csv")
hb21_titles = pd.read_csv(hb21)
hb21_titles.set_index("Title")
# Out:
#                                                                                                Genres  \
# Title
# Scenes from a Marriage                                     Action, Fantasy, Mystery, Sci-Fi, Thriller
# The White Lotus                                                   Action, Adventure, Fantasy, Mystery
# Mare of Easttown                                                                                Drama
# American Horror Stories                                               Crime, Drama, Mystery, Thriller
# Hacks                                                                           Comedy, Drama, Family
# Superman and Lois                                              Action, Comedy, Drama, Fantasy, Sci-Fi
# The Premise                                                 Action, Adventure, Drama, Romance, Sci-Fi
# Tokyo Revengers                                                                  Action, Crime, Drama
# Walker                                                               Action, Adventure, Drama, Sci-Fi
# The Nevers                                          Adventure, Drama, Fantasy, Horror, Sci-Fi, Thr...
# The Way Down: God, Greed and the Cult of Gwen S...            Action, Crime, Drama, Mystery, Thriller
# It's a Sin                                                           Drama, Mystery, Sci-Fi, Thriller
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Scenes from a Marriage                               8.0               86
# The White Lotus                                      7.7               76
# Mare of Easttown                                     8.5               93
# American Horror Stories                              6.1               37
# Hacks                                                8.2               87
# Superman and Lois                                    7.9               70
# The Premise                                          6.1               40
# Tokyo Revengers                                      8.4               50
# Walker                                               6.0               71
# The Nevers                                           7.4               83
# The Way Down: God, Greed and the Cult of Gwen S...   7.4               67
# It's a Sin                                           8.7               92

# %%
titles_hb21 = len(hb21_titles["Title"].unique())
titles_hb21
# Out:
# 12

# %%
hb_imdb_21 = hb21_titles["IMDb"].mean()
hb_imdb_21.round(1)
# Out:
# 7.5

# %%
hb_top10_imdb_21 = hb21_titles.sort_values("IMDb", ascending=False)
hb_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                                                Genres  \
# Title
# It's a Sin                                                           Drama, Mystery, Sci-Fi, Thriller
# Mare of Easttown                                                                                Drama
# Tokyo Revengers                                                                  Action, Crime, Drama
# Hacks                                                                           Comedy, Drama, Family
# Scenes from a Marriage                                     Action, Fantasy, Mystery, Sci-Fi, Thriller
# Superman and Lois                                              Action, Comedy, Drama, Fantasy, Sci-Fi
# The White Lotus                                                   Action, Adventure, Fantasy, Mystery
# The Nevers                                          Adventure, Drama, Fantasy, Horror, Sci-Fi, Thr...
# The Way Down: God, Greed and the Cult of Gwen S...            Action, Crime, Drama, Mystery, Thriller
# American Horror Stories                                               Crime, Drama, Mystery, Thriller
#
#                                                     IMDb  Rotten Tomatoes
# Title
# It's a Sin                                           8.7               92
# Mare of Easttown                                     8.5               93
# Tokyo Revengers                                      8.4               50
# Hacks                                                8.2               87
# Scenes from a Marriage                               8.0               86
# Superman and Lois                                    7.9               70
# The White Lotus                                      7.7               76
# The Nevers                                           7.4               83
# The Way Down: God, Greed and the Cult of Gwen S...   7.4               67
# American Horror Stories                              6.1               37

# %%
hb_rot_21 = hb21_titles["Rotten Tomatoes"].mean()
hb_rot_21.round(1)
# Out:
# 71.0

# %%
hb_top10_rot_21 = hb21_titles.sort_values("Rotten Tomatoes", ascending=False)
hb_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                                                Genres  \
# Title
# Mare of Easttown                                                                                Drama
# It's a Sin                                                           Drama, Mystery, Sci-Fi, Thriller
# Hacks                                                                           Comedy, Drama, Family
# Scenes from a Marriage                                     Action, Fantasy, Mystery, Sci-Fi, Thriller
# The Nevers                                          Adventure, Drama, Fantasy, Horror, Sci-Fi, Thr...
# The White Lotus                                                   Action, Adventure, Fantasy, Mystery
# Walker                                                               Action, Adventure, Drama, Sci-Fi
# Superman and Lois                                              Action, Comedy, Drama, Fantasy, Sci-Fi
# The Way Down: God, Greed and the Cult of Gwen S...            Action, Crime, Drama, Mystery, Thriller
# Tokyo Revengers                                                                  Action, Crime, Drama
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Mare of Easttown                                     8.5               93
# It's a Sin                                           8.7               92
# Hacks                                                8.2               87
# Scenes from a Marriage                               8.0               86
# The Nevers                                           7.4               83
# The White Lotus                                      7.7               76
# Walker                                               6.0               71
# Superman and Lois                                    7.9               70
# The Way Down: God, Greed and the Cult of Gwen S...   7.4               67
# Tokyo Revengers                                      8.4               50

# %%
# Apple
a19 = Path("Resources/Apple/a_19.csv")
a19_titles = pd.read_csv(a19)
a19_titles.set_index("Title")
# Out:
#                          Genres  IMDb  Rotten Tomatoes
# Title
# Modern Love       Drama, Sci-Fi   8.0               59
# The Morning Show          Drama   8.4               80
# Servant                   Drama   7.5               76
# Dickinson                 Drama   7.4               86

# %%
titles_a19 = len(a19_titles["Title"].unique())
titles_a19
# Out:
# 4

# %%
a_imdb_19 = a19_titles["IMDb"].mean()
a_imdb_19.round(1)
# Out:
# 7.8

# %%
a_top10_imdb_19 = a19_titles.sort_values("IMDb", ascending=False)
a_top10_imdb_19.set_index("Title").head(10)
# Out:
#                          Genres  IMDb  Rotten Tomatoes
# Title
# The Morning Show          Drama   8.4               80
# Modern Love       Drama, Sci-Fi   8.0               59
# Servant                   Drama   7.5               76
# Dickinson                 Drama   7.4               86

# %%
a_rot_19 = a19_titles["Rotten Tomatoes"].mean()
a_rot_19.round(1)
# Out:
# 75.2

# %%
a_top10_rot_19 = a19_titles.sort_values("Rotten Tomatoes", ascending=False)
a_top10_rot_19.head(10)
# Out:
#           Genres  IMDb  Rotten Tomatoes             Title
# 3          Drama   7.4               86         Dickinson
# 1          Drama   8.4               80  The Morning Show
# 2          Drama   7.5               76           Servant
# 0  Drama, Sci-Fi   8.0               59       Modern Love

# %%
a20 = Path("Resources/Apple/a_20.csv")
a20_titles = pd.read_csv(a20)
a20_titles.set_index("Title")
# Out:
#                                       Genres  IMDb  Rotten Tomatoes
# Title
# Defending Jacob                        Drama   7.9               89
# Little Voice                           Drama   7.2               80
# Home Before Dark            Mystery thriller   7.5               82
# For All Mankind                      History   7.9               85
# Trying                                 Drama   7.7               94
# Little America                        Comedy   7.5               78
# Central Park                       Animation   6.8               78
# Mythic Quest                          Comedy   7.7               85
# Visible: Out on Television             LGBTQ   7.4              100
# Ted Lasso                             Comedy   8.8               95

# %%
titles_a20 = len(a20_titles["Title"].unique())
titles_a20
# Out:
# 10

# %%
a_imdb_20 = a20_titles["IMDb"].mean()
a_imdb_20.round(1)
# Out:
# 7.6

# %%
a_top10_imdb_20 = a20_titles.sort_values("IMDb", ascending=False)
a_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                       Genres  IMDb  Rotten Tomatoes
# Title
# Ted Lasso                             Comedy   8.8               95
# Defending Jacob                        Drama   7.9               89
# For All Mankind                      History   7.9               85
# Trying                                 Drama   7.7               94
# Mythic Quest                          Comedy   7.7               85
# Home Before Dark            Mystery thriller   7.5               82
# Little America                        Comedy   7.5               78
# Visible: Out on Television             LGBTQ   7.4              100
# Little Voice                           Drama   7.2               80
# Central Park                       Animation   6.8               78

# %%
a_rot_20 = a20_titles["Rotten Tomatoes"].mean()
a_rot_20.round(1)
# Out:
# 86.6

# %%
a_top10_rot_20 = a20_titles.sort_values("Rotten Tomatoes", ascending=False)
a_top10_rot_20.set_index("Title").head(10)
# Out:
#                                       Genres  IMDb  Rotten Tomatoes
# Title
# Visible: Out on Television             LGBTQ   7.4              100
# Ted Lasso                             Comedy   8.8               95
# Trying                                 Drama   7.7               94
# Defending Jacob                        Drama   7.9               89
# For All Mankind                      History   7.9               85
# Mythic Quest                          Comedy   7.7               85
# Home Before Dark            Mystery thriller   7.5               82
# Little Voice                           Drama   7.2               80
# Little America                        Comedy   7.5               78
# Central Park                       Animation   6.8               78

# %%
a21 = Path("Resources/Apple/a_21.csv")
a21_titles = pd.read_csv(a21)
a21_titles.set_index("Title")
# Out:
#                                                                        Genres  \
# Title
# Nine Perfect Strangers                                          Drama, Sci-Fi
# Invincible                                    Crime, Drama, Mystery, Thriller
# He-Man and the Masters of the Universe                        Comedy, Musical
# Physical                                                               Comedy
# Mr. Corman                                                              Drama
# Foundation                                                              Scifi
# Losing Alice                                                            Drama
# The Me You Can't See                                          Health wellness
# Schmigadoon!                                                          Musical
# Calls                                                                  Horror
# 1971: The Year that Music Changed Everything                      Documentary
#
#                                               IMDb  Rotten Tomatoes
# Title
# Nine Perfect Strangers                         7.1               95
# Invincible                                     8.7               91
# He-Man and the Masters of the Universe         6.2               77
# Physical                                       7.3               80
# Mr. Corman                                     6.4               66
# Foundation                                     7.5               60
# Losing Alice                                   6.6               75
# The Me You Can't See                           5.3               68
# Schmigadoon!                                   7.3               85
# Calls                                          7.7               86
# 1971: The Year that Music Changed Everything   7.5               62

# %%
titles_a21 = len(a21_titles["Title"].unique())
titles_a21
# Out:
# 11

# %%
a_imdb_21 = a21_titles["IMDb"].mean()
a_imdb_21.round(1)
# Out:
# 7.1

# %%
a_top10_imdb_21 = a21_titles.sort_values("IMDb", ascending=False)
a_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                        Genres  \
# Title
# Invincible                                    Crime, Drama, Mystery, Thriller
# Calls                                                                  Horror
# Foundation                                                              Scifi
# 1971: The Year that Music Changed Everything                      Documentary
# Physical                                                               Comedy
# Schmigadoon!                                                          Musical
# Nine Perfect Strangers                                          Drama, Sci-Fi
# Losing Alice                                                            Drama
# Mr. Corman                                                              Drama
# He-Man and the Masters of the Universe                        Comedy, Musical
#
#                                               IMDb  Rotten Tomatoes
# Title
# Invincible                                     8.7               91
# Calls                                          7.7               86
# Foundation                                     7.5               60
# 1971: The Year that Music Changed Everything   7.5               62
# Physical                                       7.3               80
# Schmigadoon!                                   7.3               85
# Nine Perfect Strangers                         7.1               95
# Losing Alice                                   6.6               75
# Mr. Corman                                     6.4               66
# He-Man and the Masters of the Universe         6.2               77

# %%
a_rot_21 = a21_titles["Rotten Tomatoes"].mean()
a_rot_21.round(1)
# Out:
# 76.8

# %%
a_top10_rot_21 = a21_titles.sort_values("Rotten Tomatoes", ascending=False)
a_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                        Genres  \
# Title
# Nine Perfect Strangers                                          Drama, Sci-Fi
# Invincible                                    Crime, Drama, Mystery, Thriller
# Calls                                                                  Horror
# Schmigadoon!                                                          Musical
# Physical                                                               Comedy
# He-Man and the Masters of the Universe                        Comedy, Musical
# Losing Alice                                                            Drama
# The Me You Can't See                                          Health wellness
# Mr. Corman                                                              Drama
# 1971: The Year that Music Changed Everything                      Documentary
#
#                                               IMDb  Rotten Tomatoes
# Title
# Nine Perfect Strangers                         7.1               95
# Invincible                                     8.7               91
# Calls                                          7.7               86
# Schmigadoon!                                   7.3               85
# Physical                                       7.3               80
# He-Man and the Masters of the Universe         6.2               77
# Losing Alice                                   6.6               75
# The Me You Can't See                           5.3               68
# Mr. Corman                                     6.4               66
# 1971: The Year that Music Changed Everything   7.5               62

# %%
# Hulu
h19 = Path("Resources/Hulu/h_19.csv")
h19_titles = pd.read_csv(h19)
h19_titles.set_index("Title")
# Out:
#                                                                  Genres  IMDb  \
# Title
# Framing John DeLorean                       Documentary,Biography,Drama   6.4
# Parasite                                          Comedy,Drama,Thriller   8.6
# Portrait of a Lady on Fire                                Drama,Romance   8.1
# Rocketman                                 Biography,Drama,Music,Musical   7.3
# Booksmart                                                        Comedy   7.2
# ...                                                                 ...   ...
# Curious George: Royal Monkey  Animation,Adventure,Comedy,Family,Fantasy   5.1
# Drag Kids                                                   Documentary   5.1
# After Parkland                                              Documentary   6.0
# Where We Go from Here                                             Drama   4.9
# Zoo-Head                                                Sci-Fi,Thriller   3.6
#
#                               Rotten Tomatoes
# Title
# Framing John DeLorean                      59
# Parasite                                   88
# Portrait of a Lady on Fire                 80
# Rocketman                                  79
# Booksmart                                  78
# ...                                       ...
# Curious George: Royal Monkey               41
# Drag Kids                                  41
# After Parkland                             40
# Where We Go from Here                      39
# Zoo-Head                                   39
#
# [156 rows x 3 columns]

# %%
titles_h19 = len(h19_titles["Title"].unique())
titles_h19
# Out:
# 156

# %%
h_imdb_19 = h19_titles["IMDb"].mean()
h_imdb_19.round(1)
# Out:
# 6.0

# %%
h_top10_imdb_19 = h19_titles.sort_values("IMDb", ascending=False)
h_top10_imdb_19.set_index("Title").head(10)
# Out:
#                                                                                      Genres  \
# Title
# Parasite                                                              Comedy,Drama,Thriller
# The Biggest Little Farm                                                         Documentary
# Portrait of a Lady on Fire                                                    Drama,Romance
# Raise Hell: The Life & Times of Molly Ivins                                     Documentary
# Honeyland                                                                 Documentary,Drama
# Ask Dr. Ruth                                                          Documentary,Biography
# Margaret Atwood: A Word After a Word After a Wo...                    Documentary,Biography
# Hotel Mumbai                                                  Action,Drama,History,Thriller
# The Peanut Butter Falcon                                             Adventure,Comedy,Drama
# The Cave                                            Action,Adventure,Horror,Sci-Fi,Thriller
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Parasite                                             8.6               88
# The Biggest Little Farm                              8.1               69
# Portrait of a Lady on Fire                           8.1               80
# Raise Hell: The Life & Times of Molly Ivins          8.1               51
# Honeyland                                            8.0               70
# Ask Dr. Ruth                                         7.7               54
# Margaret Atwood: A Word After a Word After a Wo...   7.6               53
# Hotel Mumbai                                         7.6               75
# The Peanut Butter Falcon                             7.6               78
# The Cave                                             7.5               61

# %%
h_rot_19 = p19_titles["Rotten Tomatoes"].mean()
h_rot_19.round(1)
# Out:
# 51.7

# %%
h_top10_rot_19 = h19_titles.sort_values("Rotten Tomatoes", ascending=False)
h_top10_rot_19.set_index("Title").head(10)
# Out:
#                                                    Genres  IMDb  \
# Title
# Parasite                            Comedy,Drama,Thriller   8.6
# Portrait of a Lady on Fire                  Drama,Romance   8.1
# Rocketman                   Biography,Drama,Music,Musical   7.3
# Booksmart                                          Comedy   7.2
# The Peanut Butter Falcon           Adventure,Comedy,Drama   7.6
# Fighting With My Family      Biography,Comedy,Drama,Sport   7.1
# Terminator: Dark Fate             Action,Adventure,Sci-Fi   6.2
# Bombshell                                 Biography,Drama   6.8
# The Upside                                   Comedy,Drama   7.0
# Hotel Mumbai                Action,Drama,History,Thriller   7.6
#
#                             Rotten Tomatoes
# Title
# Parasite                                 88
# Portrait of a Lady on Fire               80
# Rocketman                                79
# Booksmart                                78
# The Peanut Butter Falcon                 78
# Fighting With My Family                  77
# Terminator: Dark Fate                    76
# Bombshell                                76
# The Upside                               75
# Hotel Mumbai                             75

# %%
h20 = Path("Resources/Hulu/h_20.csv")
h20_titles = pd.read_csv(h20)
h20_titles.set_index("Title")
# Out:
#                                                  Genres  IMDb  Rotten Tomatoes
# Title
# MOTHER                             Drama,Horror,Mystery   6.8               55
# Born to Play                                Documentary   6.3               49
# Happiest Season       Comedy,Crime,Drama,Horror,Romance   6.6               83
# Big Time Adolescence                       Comedy,Drama   7.0               83
# Another Round                              Comedy,Drama   7.8               80
# ...                                                 ...   ...              ...
# How to Fake a War                                Comedy   4.4               44
# Endless                           Drama,Fantasy,Romance   4.8               43
# Naughty Books                               Documentary   6.4               42
# Carrion                                          Horror   2.9               39
# A Christmas Hero                   Drama,Family,Fantasy   4.4               39
#
# [114 rows x 3 columns]

# %%
titles_h20 = len(h20_titles["Title"].unique())
titles_h20
# Out:
# 114

# %%
h_imdb_20 = h20_titles["IMDb"].mean()
h_imdb_20.round(1)
# Out:
# 5.9

# %%
h_top10_imdb_20 = h20_titles.sort_values("IMDb", ascending=False)
h_top10_imdb_20.set_index("Title").head(10)
# Out:
#                                                                       Genres  \
# Title
# Derek DelGaudio's In & of Itself                                 Documentary
# Collective                                                       Documentary
# Crock of Gold: A Few Rounds with Shane MacGowan  Documentary,Biography,Music
# The Story of Soaps                                                   History
# Another Round                                                   Comedy,Drama
# Totally Under Control                                            Documentary
# The Mole Agent                                                   Documentary
# The Orange Years: The Nickelodeon Story                          Documentary
# The Painter and the Thief                                        Documentary
# Zappa                                            Documentary,Biography,Music
#
#                                                  IMDb  Rotten Tomatoes
# Title
# Derek DelGaudio's In & of Itself                  8.3               67
# Collective                                        8.2               79
# Crock of Gold: A Few Rounds with Shane MacGowan   7.9               58
# The Story of Soaps                                7.8               44
# Another Round                                     7.8               80
# Totally Under Control                             7.7               64
# The Mole Agent                                    7.7               74
# The Orange Years: The Nickelodeon Story           7.6               58
# The Painter and the Thief                         7.6               62
# Zappa                                             7.6               68

# %%
h_rot_20 = h20_titles["Rotten Tomatoes"].mean()
h_rot_20.round(1)
# Out:
# 57.8

# %%
h_top10_rot_20 = h20_titles.sort_values("Rotten Tomatoes", ascending=False)
h_top10_rot_20.set_index("Title").head(10)
# Out:
#                                                               Genres  IMDb  \
# Title
# Happiest Season                    Comedy,Crime,Drama,Horror,Romance   6.6
# Big Time Adolescence                                    Comedy,Drama   7.0
# Another Round                                           Comedy,Drama   7.8
# Palm Springs                          Comedy,Fantasy,Mystery,Romance   7.4
# Collective                                               Documentary   8.2
# Run                                                 Mystery,Thriller   6.7
# The Mole Agent                                           Documentary   7.7
# The Croods 2               Animation,Adventure,Comedy,Family,Fantasy   7.0
# Bill & Ted Face the Music              Adventure,Comedy,Music,Sci-Fi   6.0
# Sputnik                                      Action,Adventure,Sci-Fi   6.4
#
#                            Rotten Tomatoes
# Title
# Happiest Season                         83
# Big Time Adolescence                    83
# Another Round                           80
# Palm Springs                            79
# Collective                              79
# Run                                     74
# The Mole Agent                          74
# The Croods 2                            73
# Bill & Ted Face the Music               72
# Sputnik                                 70

# %%
h21 = Path("Resources/Hulu/h_21.csv")
h21_titles = pd.read_csv(h21)
h21_titles.set_index("Title")
# Out:
#                                                                             Genres  \
# Title
# Nomadland                                                                    Drama
# Boss Level                                          Action,Mystery,Sci-Fi,Thriller
# Barb & Star Go to Vista Del Mar                                             Comedy
# Summer of Soul (...or, When the Revolution Coul...               Documentary,Music
# Quo vadis, Aida?                                                 Drama,History,War
# Plan B                                                                      Comedy
# Willy's Wonderland                                   Action,Comedy,Horror,Thriller
# Some Kind of Heaven                                                    Documentary
# The United States vs. Billie Holiday                         Biography,Drama,Music
# Silk Road                                                     Crime,Drama,Thriller
# Shadow in the Cloud                                              Action,Horror,War
# Fear of Rain                                                 Drama,Horror,Thriller
# Framing Britney Spears                                                 Documentary
# Little Fish                                                   Drama,Romance,Sci-Fi
# The Trip to Greece                                                    Comedy,Drama
# MLK/FBI                                                                Documentary
# kid 90                                               Documentary,Biography,History
# The Outside Story                                                            Drama
# WeWork: or The Making and Breaking of a $47 Bil...                     Documentary
# Night of the Kings                                                   Drama,Fantasy
# False Positive                                             Horror,Mystery,Thriller
# Bad Hair                                                       Comedy,Horror,Music
# A Glitch in the Matrix                                                 Documentary
# Buddy Games                                                                 Comedy
# Dark Web: Cicada 3301                                       Action,Comedy,Thriller
# The Ultimate Playlist of Noise                                  Comedy,Drama,Music
# 69: The Saga of Danny Hernandez                                  Documentary,Music
# The Resort                                                                  Horror
# Dr. Bird's Advice for Sad Poets                               Comedy,Drama,Mystery
# Phobias                                                            Horror,Thriller
# Stars Fell on Alabama                                         Comedy,Drama,Romance
# Olympic Dreams Featuring Jonas Brothers                                      Sport
# Dreamcatcher                                               Horror,Mystery,Thriller
# North Korea: Inside The Mind of a Dictator                             Documentary
# Safer at Home                                                             Thriller
# GameStopped                                                            Documentary
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Nomadland                                            7.4               79
# Boss Level                                           6.9               75
# Barb & Star Go to Vista Del Mar                      6.4               73
# Summer of Soul (...or, When the Revolution Coul...   8.3               72
# Quo vadis, Aida?                                     7.9               71
# Plan B                                               6.7               70
# Willy's Wonderland                                   5.5               69
# Some Kind of Heaven                                  7.2               68
# The United States vs. Billie Holiday                 6.3               67
# Silk Road                                            5.9               65
# Shadow in the Cloud                                  4.8               65
# Fear of Rain                                         5.9               64
# Framing Britney Spears                               6.9               64
# Little Fish                                          6.9               63
# The Trip to Greece                                   6.6               63
# MLK/FBI                                              6.9               62
# kid 90                                               6.9               62
# The Outside Story                                    6.1               61
# WeWork: or The Making and Breaking of a $47 Bil...   6.6               61
# Night of the Kings                                   6.5               59
# False Positive                                       4.6               59
# Bad Hair                                             5.5               58
# A Glitch in the Matrix                               5.2               58
# Buddy Games                                          4.8               57
# Dark Web: Cicada 3301                                4.9               56
# The Ultimate Playlist of Noise                       6.6               54
# 69: The Saga of Danny Hernandez                      5.3               53
# The Resort                                           3.3               52
# Dr. Bird's Advice for Sad Poets                      6.1               51
# Phobias                                              3.6               51
# Stars Fell on Alabama                                5.5               51
# Olympic Dreams Featuring Jonas Brothers              8.5               48
# Dreamcatcher                                         2.6               47
# North Korea: Inside The Mind of a Dictator           6.7               44
# Safer at Home                                        4.5               44
# GameStopped                                          3.9               41

# %%
titles_h21 = len(h21_titles["Title"].unique())
titles_h21
# Out:
# 36

# %%
h_imdb_21 = h21_titles["IMDb"].mean()
h_imdb_21.round(1)
# Out:
# 5.9

# %%
h_top10_imdb_21 = h21_titles.sort_values("IMDb", ascending=False)
h_top10_imdb_21.set_index("Title").head(10)
# Out:
#                                                                             Genres  \
# Title
# Olympic Dreams Featuring Jonas Brothers                                      Sport
# Summer of Soul (...or, When the Revolution Coul...               Documentary,Music
# Quo vadis, Aida?                                                 Drama,History,War
# Nomadland                                                                    Drama
# Some Kind of Heaven                                                    Documentary
# Boss Level                                          Action,Mystery,Sci-Fi,Thriller
# kid 90                                               Documentary,Biography,History
# MLK/FBI                                                                Documentary
# Framing Britney Spears                                                 Documentary
# Little Fish                                                   Drama,Romance,Sci-Fi
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Olympic Dreams Featuring Jonas Brothers              8.5               48
# Summer of Soul (...or, When the Revolution Coul...   8.3               72
# Quo vadis, Aida?                                     7.9               71
# Nomadland                                            7.4               79
# Some Kind of Heaven                                  7.2               68
# Boss Level                                           6.9               75
# kid 90                                               6.9               62
# MLK/FBI                                              6.9               62
# Framing Britney Spears                               6.9               64
# Little Fish                                          6.9               63

# %%
h_rot_21 = h21_titles["Rotten Tomatoes"].mean()
h_rot_21.round(1)
# Out:
# 59.9

# %%
h_top10_rot_21 = h21_titles.sort_values("Rotten Tomatoes", ascending=False)
h_top10_rot_21.set_index("Title").head(10)
# Out:
#                                                                             Genres  \
# Title
# Nomadland                                                                    Drama
# Boss Level                                          Action,Mystery,Sci-Fi,Thriller
# Barb & Star Go to Vista Del Mar                                             Comedy
# Summer of Soul (...or, When the Revolution Coul...               Documentary,Music
# Quo vadis, Aida?                                                 Drama,History,War
# Plan B                                                                      Comedy
# Willy's Wonderland                                   Action,Comedy,Horror,Thriller
# Some Kind of Heaven                                                    Documentary
# The United States vs. Billie Holiday                         Biography,Drama,Music
# Silk Road                                                     Crime,Drama,Thriller
#
#                                                     IMDb  Rotten Tomatoes
# Title
# Nomadland                                            7.4               79
# Boss Level                                           6.9               75
# Barb & Star Go to Vista Del Mar                      6.4               73
# Summer of Soul (...or, When the Revolution Coul...   8.3               72
# Quo vadis, Aida?                                     7.9               71
# Plan B                                               6.7               70
# Willy's Wonderland                                   5.5               69
# Some Kind of Heaven                                  7.2               68
# The United States vs. Billie Holiday                 6.3               67
# Silk Road                                            5.9               65

# %%
plotdata = pd.DataFrame({
    "Prime":[titles_p19, titles_p20, titles_p21],
    "Netflix":[titles_n19, titles_n20, titles_n21],
    "Disney":[titles_d19, titles_d20, titles_d21],
    "HBO":[titles_hb19, titles_hb20, titles_hb21],
    "AppleTV":[titles_a19, titles_a20, titles_a21],
    "Hulu" :[titles_h19, titles_h20, titles_h21]
    }, 
    index=["2019", "2020", "2021"]
)

plotdata.plot(kind="bar", align="center")
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Series Produced per Streaming Service")
plt.xlabel("Streaming Service")
plt.ylabel("Number of New Shows")
# Out:
# Text(0, 0.5, 'Number of New Shows')

# %%
plotdata = pd.DataFrame({
    "Prime":[p_imdb_19, p_imdb_20, p_imdb_21],
    "Netflix":[n_imdb_19, n_imdb_20, n_imdb_21],
    "Disney":[d_imdb_19, d_imdb_20, d_imdb_21],
    "HBO":[hb_imdb_19, hb_imdb_20, hb_imdb_21],
    "AppleTV":[h_imdb_19, h_imdb_20, h_imdb_21],
    "Hulu" :[h_imdb_19, h_imdb_20, h_imdb_21]
    }, 
    index=["2019", "2020", "2021"]
)

plotdata.plot(kind="bar").legend(loc='upper right', ncol=3)
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Average IMDb Score of Series by Streaming Service")
plt.ylim(5.5,8.0, .1)
plt.xlabel("Streaming Service")
plt.ylabel("IMDb Score (avg)")
# Out:
# Text(0, 0.5, 'IMDb Score (avg)')

# %%
plotdata = pd.DataFrame({
    "Prime":[p_rot_19, p_rot_20, p_rot_21],
    "Netflix":[n_rot_19, n_rot_20, n_rot_21],
    "Disney":[d_rot_19, d_rot_20, d_rot_21],
    "HBO":[hb_rot_19, hb_rot_20, hb_rot_21],
    "AppleTV":[a_rot_19, a_rot_20, a_rot_21],
    "Hulu" :[h_rot_19, h_rot_20, h_rot_21]
    }, 
    index=["2019", "2020", "2021"]
)

plotdata.plot(kind="bar", align="center").legend(loc='upper right', ncol=3)
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Average Rotten Tomatoe Score of Series by Streaming Service")
plt.ylim(45,91)
plt.xlabel("Streaming Service")
plt.ylabel("Tomatoe Score (avg)")
# Out:
# Text(0, 0.5, 'Tomatoe Score (avg)')
